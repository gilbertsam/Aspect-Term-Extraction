# %%
import re
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from pathlib import Path
import nltk

datalatih=Path.cwd().parent.joinpath(r'C:\Users\USER\Documents\DataScience\Skripsiiuu\ATE-XGBoost\Dataset\train.xml')

extract=None
with datalatih.open(encoding="utf-8")as f:
    extract=BeautifulSoup(f.read().strip(),"lxml-xml")
if extract is None:
    raise Exception("Data XML not found")
sentence_nodes=extract.find_all("sentence")

# %%
sentence_nodes
# Out:
# [<sentence id="1004293:0">
#  <text>Judging from previous posts this used to be a good place, but not any longer.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="51" polarity="negative" target="place" to="56"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1004293:1">
#  <text>We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="75" polarity="negative" target="staff" to="80"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1004293:2">
#  <text>They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1004293:3">
#  <text>The food was lousy - too sweet or too salty and the portions tiny.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="negative" target="food" to="8"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="52" polarity="negative" target="portions" to="60"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1004293:4">
#  <text>After all that, they complained to me about the small tip.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1004293:5">
#  <text>Avoid this place!</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="11" polarity="negative" target="place" to="16"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1014458:0">
#  <text>I have eaten at Saul, many times, the food is always consistently, outrageously good.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="38" polarity="positive" target="food" to="42"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1014458:1">
#  <text>Saul is the best restaurant on Smith Street and in Brooklyn.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="Saul" to="4"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1014458:2">
#  <text>The duck confit is always amazing and the foie gras terrine with figs was out of this world.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="42" polarity="positive" target="foie gras terrine with figs" to="69"/>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="duck confit" to="15"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1014458:3">
#  <text>The wine list is interesting and has many good values.</text>
#  <Opinions>
#  <Opinion category="DRINKS#STYLE_OPTIONS" from="4" polarity="positive" target="wine list" to="13"/>
#  <Opinion category="DRINKS#PRICES" from="4" polarity="positive" target="wine list" to="13"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1014458:4">
#  <text>For the price, you cannot eat this well in Manhattan.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#PRICES" from="0" polarity="positive" target="NULL" to="0"/>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1016296:0">
#  <text>I was very disappointed with this restaurant.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="34" polarity="negative" target="restaurant" to="44"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1016296:1">
#  <text>Ive asked a cart attendant for a lotus leaf wrapped rice and she replied back rice and just walked away.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="12" polarity="negative" target="cart attendant" to="26"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1016296:2">
#  <text>I had to ask her three times before she finally came back with the dish Ive requested.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1016296:3">
#  <text>Food was okay, nothing great.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="neutral" target="Food" to="4"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1016296:4">
#  <text>Chow fun was dry; pork shu mai was more than usually greasy and had to share a table with loud and rude family. </text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="negative" target="Chow fun" to="8"/>
#  <Opinion category="FOOD#QUALITY" from="18" polarity="negative" target="pork shu mai" to="30"/>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1016296:5">
#  <text>I/we will never go back to this place again.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="32" polarity="negative" target="place" to="37"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1028246:0">
#  <text>Went on a 3 day oyster binge, with Fish bringing up the closing, and I am so glad this was the place it O trip ended, because it was so great!</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="35" polarity="positive" target="Fish" to="39"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1028246:1">
#  <text>Service was devine, oysters where a sensual as they come, and the price can't be beat!!!</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="Service" to="7"/>
#  <Opinion category="FOOD#QUALITY" from="20" polarity="positive" target="oysters" to="27"/>
#  <Opinion category="RESTAURANT#PRICES" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1028246:2">
#  <text>You can't go wrong here.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1032695:0">
#  <text>Every time in New York I make it a point to visit Restaurant Saul on Smith Street.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="50" polarity="positive" target="Restaurant Saul" to="65"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1032695:1">
#  <text>Everything is always cooked to perfection, the service is excellent, the decor cool and understated.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="NULL" to="0"/>
#  <Opinion category="SERVICE#GENERAL" from="47" polarity="positive" target="service" to="54"/>
#  <Opinion category="AMBIENCE#GENERAL" from="73" polarity="positive" target="decor" to="78"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1032695:2">
#  <text>I had the duck breast special on my last visit and it was incredible.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="10" polarity="positive" target="duck breast special" to="29"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1032695:3">
#  <text>Can't wait wait for my next visit.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1041457:0">
#  <text>I had my eyes on this place, promising myself I will one day 'give it a try.' </text>
#  </sentence>,
#  <sentence id="1041457:1">
#  <text>And I hate to say this but I doubt I'll ever go back. </text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1041457:2">
#  <text>The food is very average...the Thai fusion stuff is a bit too sweet, every thing they serve is too sweet here.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="negative" target="food" to="8"/>
#  <Opinion category="FOOD#QUALITY" from="31" polarity="negative" target="Thai fusion stuff" to="48"/>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1041457:3">
#  <text>The only thing I moderately enjoyed was their Grilled Chicken special with Edamame Puree.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="46" polarity="positive" target="Grilled Chicken special with Edamame Puree" to="88"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1041457:4">
#  <text>I had never had Edamame pureed before but I thought it was innovative and tasty (could've used a bit more salt).</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="16" polarity="positive" target="Edamame pureed" to="30"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="16" polarity="positive" target="Edamame pureed" to="30"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="1041457:5">
#  <text>Anyways, if you're in the neighborhood to eat good food, I wouldn't waste my time trying to find something, rather go across the street to Tamari.</text>
#  </sentence>,
#  <sentence id="1041457:6">
#  <text>The decor is night tho...but they REALLY need to clean that vent in the ceiling...its quite un-appetizing, and kills your effort to make this place look sleek and modern.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="142" polarity="negative" target="place" to="147"/>
#  <Opinion category="AMBIENCE#GENERAL" from="4" polarity="positive" target="decor" to="9"/>
#  <Opinion category="AMBIENCE#GENERAL" from="60" polarity="negative" target="vent" to="64"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1053543:0">
#  <text>We ate outside at Haru's Sake bar because Haru's restaurant next door was overflowing.</text>
#  </sentence>,
#  <sentence id="1053543:1">
#  <text>What's the difference between the two?</text>
#  </sentence>,
#  <sentence id="1053543:2">
#  <text>Their sake list was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!</text>
#  <Opinions>
#  <Opinion category="DRINKS#STYLE_OPTIONS" from="6" polarity="positive" target="sake list" to="15"/>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1053543:3">
#  <text>The spicy tuna roll was unusually good and the rock shrimp tempura was awesome, great appetizer to share!</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="spicy tuna roll" to="19"/>
#  <Opinion category="FOOD#QUALITY" from="47" polarity="positive" target="rock shrimp tempura" to="66"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1053543:4">
#  <text>We went around 9:30 on a Friday and it had died down a bit by then so the service was great!</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="74" polarity="positive" target="service" to="81"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1055910:0">
#  <text>we love th pink pony.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="11" polarity="positive" target="pink pony" to="20"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1055910:1">
#  <text>THe perfect spot.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="12" polarity="positive" target="spot" to="16"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1055910:2">
#  <text>Food-awesome.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="Food" to="4"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1055910:3">
#  <text>Service- friendly and attentive.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="Service" to="7"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1055910:4">
#  <text>Ambiance- relaxed and stylish.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="0" polarity="positive" target="Ambiance" to="8"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1055910:5">
#  <text>Don't judge this place prima facie, you have to try it to believe it, a home away from home for the literate heart.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="17" polarity="positive" target="place" to="22"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1058221:0">
#  <text>i have eaten here a handful of times, for no reason besides sheer convenience.</text>
#  </sentence>,
#  <sentence id="1058221:1">
#  <text>(i hang out, and live, in the neighborhood..) </text>
#  </sentence>,
#  <sentence id="1058221:2">
#  <text>the food is decent.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="neutral" target="food" to="8"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1058221:3">
#  <text>however, it's the service that leaves a bad taste in my mouth.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="18" polarity="negative" target="service" to="25"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1058221:4">
#  <text>i happen to have a policy that goes along with a little bit of self-respect, which includes not letting a waiter intimidate me, i.e. make me feel bad asking for trivialities like water, or the check.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="106" polarity="negative" target="waiter" to="112"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1058221:5">
#  <text>i know, you were too busy showing off your vintage tee shirt and looking bored, but my agenda is i'm here to eat and enjoy the company of friends, seeking a pleasant experience.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1058221:6">
#  <text>well, i didn't find it there, and trust, i have told everyone i can think of about my experience. </text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1058221:7">
#  <text>the last time i walked by it looked pretty empty. hmmm.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1062641:0">
#  <text>This place has got to be the best japanese restaurant in the new york area.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="5" polarity="positive" target="place" to="10"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1062641:1">
#  <text>I had a great experience.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1062641:2">
#  <text>Food is great.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="Food" to="4"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1062641:3">
#  <text>Service is top notch.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="Service" to="7"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1062641:4">
#  <text>I have been going back again and again.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1064477:0">
#  <text>I tend to judge a sushi restaurant by its sea urchin, which was heavenly at sushi rose.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="42" polarity="positive" target="sea urchin" to="52"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1064477:1">
#  <text>It melted in my little mouth and the perfect consistency-not too fishy, creamy, and slightly buttery.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1064477:2">
#  <text>The sushi seemed pretty fresh and was adequately proportioned.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="sushi" to="9"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="4" polarity="positive" target="sushi" to="9"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1064477:3">
#  <text>The rice to fish ration was also good--they didn't try to overpack the rice.</text>
#  <Opinions>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="4" polarity="positive" target="rice to fish ration" to="23"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1064477:4">
#  <text>We took advanatage of the half price sushi deal on saturday so it was well worth it.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="26" polarity="positive" target="half price sushi deal" to="47"/>
#  <Opinion category="FOOD#PRICES" from="26" polarity="positive" target="half price sushi deal" to="47"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1074868:0">
#  <text>I went to this restaurant with a woman that I met recently.</text>
#  </sentence>,
#  <sentence id="1074868:1">
#  <text>She lives nearby but had never gone to this establishment thinking that it might be too touristy.</text>
#  </sentence>,
#  <sentence id="1074868:2">
#  <text>Surprisingly nothing could be further from the truth.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1074868:3">
#  <text>In the evening, this place attracted a well dressed, with it, NY crowd.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="65" polarity="positive" target="crowd" to="70"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1074868:4">
#  <text>The food was well prepared and the service impecable.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="food" to="8"/>
#  <Opinion category="SERVICE#GENERAL" from="35" polarity="positive" target="service" to="42"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1074868:5">
#  <text>I'm going back.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1084394:0">
#  <text>Having hunted around for a quiet, romantic, yet not hideously expensive restaurant I stumbled across reviews for La Lanterna and gave it a shot.</text>
#  </sentence>,
#  <sentence id="1084394:1">
#  <text>Quite simply it's like stepping out of Manhattan and into a haven of tranquility.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="1084394:2">
#  <text>The service was attentive, yet unimposing, the food was far better than many notorious restaurants in Midtown and the wine list is extensive and well priced.</text>
#  </sentence>,
#  <sentence id="1084394:3">
#  <text>The Prix Fixe menu is worth every penny and you get more than enough (both in quantity AND quality).</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="Prix Fixe menu" to="18"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="4" polarity="positive" target="Prix Fixe menu" to="18"/>
#  <Opinion category="FOOD#PRICES" from="4" polarity="positive" target="Prix Fixe menu" to="18"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1084394:4">
#  <text>I will be going back and heartily recommend it!</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086415:0">
#  <text>I've had the lunch buffet at Chennai a couple of times, when I have been in the neighborhood.</text>
#  </sentence>,
#  <sentence id="1086415:1">
#  <text>It is terrific, as is the value.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="NULL" to="0"/>
#  <Opinion category="FOOD#PRICES" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086415:2">
#  <text>$6 and there is much tasty food, all of it fresh and continually refilled.</text>
#  <Opinions>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="27" polarity="positive" target="food" to="31"/>
#  <Opinion category="FOOD#QUALITY" from="27" polarity="positive" target="food" to="31"/>
#  <Opinion category="FOOD#PRICES" from="27" polarity="positive" target="food" to="31"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086415:3">
#  <text>I am not a vegetarian but, almost all the dishes were great.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="42" polarity="positive" target="dishes" to="48"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="1086415:4">
#  <text>Frankly, when you compare what you can have here for lunch, versus McDs or so many other sandwich shops in the city, there is no comparison.</text>
#  </sentence>,
#  <sentence id="1086415:5">
#  <text>Go hungry and enjoy.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086478:0">
#  <text>The food here is rather good, but only if you like to wait for it.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="food" to="8"/>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086478:1">
#  <text>I like the somosas, chai, and the chole, but the dhosas and dhal were kinda dissapointing.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="11" polarity="positive" target="somosas" to="18"/>
#  <Opinion category="FOOD#QUALITY" from="20" polarity="positive" target="chai" to="24"/>
#  <Opinion category="FOOD#QUALITY" from="34" polarity="positive" target="chole" to="39"/>
#  <Opinion category="FOOD#QUALITY" from="49" polarity="negative" target="dhosas" to="55"/>
#  <Opinion category="FOOD#QUALITY" from="60" polarity="negative" target="dhal" to="64"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086478:2">
#  <text>The service varys from day to day- sometimes they're very nice, and sometimes not.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="negative" target="service" to="11"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086478:3">
#  <text>The kitchen however, is almost always slow.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="negative" target="kitchen" to="11"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086478:4">
#  <text>Also, specify if you like your food spicy- its rather bland if you don't.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="31" polarity="negative" target="food" to="35"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1086478:5">
#  <text>The ambience is pretty and nice for conversation, so a casual lunch here would probably be best.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="4" polarity="positive" target="ambience" to="12"/>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1090587:0">
#  <text>Just went here for my girlfriends 23rd bday.</text>
#  </sentence>,
#  <sentence id="1090587:1">
#  <text>If you've ever been along the river in Weehawken you have an idea of the top of view the chart house has to offer.</text>
#  <Opinions>
#  <Opinion category="LOCATION#GENERAL" from="80" polarity="positive" target="view" to="84"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1090587:2">
#  <text>Add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="18" polarity="positive" target="service" to="25"/>
#  <Opinion category="FOOD#QUALITY" from="36" polarity="positive" target="food" to="40"/>
#  <Opinion category="FOOD#PRICES" from="36" polarity="positive" target="food" to="40"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1090587:3">
#  <text>The lava cake dessert was incredible and I recommend it.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="lava cake dessert" to="21"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1102681:0">
#  <text>Once you step into Cosette, you're miraculously in a small, off-the-beaten path Parisian bistro.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="19" polarity="positive" target="Cosette" to="26"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1102681:1">
#  <text>This tiny restaurant is as cozy as it gets, with that certain Parisian flair.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="10" polarity="positive" target="restaurant" to="20"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1102681:2">
#  <text>The food was average to above-average; the French Onion soup filling yet not overly impressive, and the desserts not brilliant in any way.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="food" to="8"/>
#  <Opinion category="FOOD#QUALITY" from="43" polarity="negative" target="French Onion soup" to="60"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="43" polarity="positive" target="French Onion soup" to="60"/>
#  <Opinion category="FOOD#QUALITY" from="104" polarity="negative" target="desserts" to="112"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1102681:3">
#  <text>However, go for the ambience, and consider the food just a companion for a trip across the world!</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="20" polarity="positive" target="ambience" to="28"/>
#  <Opinion category="FOOD#QUALITY" from="47" polarity="neutral" target="food" to="51"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1118167:0">
#  <text>I have never eaten in the restaurant, however, upon reading the reviews I got take out last week.</text>
#  </sentence>,
#  <sentence id="1118167:1">
#  <text>IT WAS HORRIBLE.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1118167:2">
#  <text>The pizza was delivered cold and the cheese wasn't even fully melted!</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="negative" target="pizza" to="9"/>
#  <Opinion category="FOOD#QUALITY" from="37" polarity="negative" target="cheese" to="43"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1118167:3">
#  <text>It looked like shredded cheese partly done - still in strips.</text>
#  <Opinions>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="1118167:4">
#  <text>I have eaten at many pizza places around NYC and this is hands down the worst.</text>
#  </sentence>,
#  <sentence id="1119578:0">
#  <text>This has got to be one of the most overrated restaurants in Brooklyn.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1119578:1">
#  <text>The pizza is overpriced and soggy.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="negative" target="pizza" to="9"/>
#  <Opinion category="FOOD#PRICES" from="4" polarity="negative" target="pizza" to="9"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1119578:2">
#  <text>Yes, they use fancy ingredients, but even fancy ingredients don't make for good pizza unless someone knows how to get the crust right.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="20" polarity="positive" target="ingredients" to="31"/>
#  <Opinion category="FOOD#QUALITY" from="80" polarity="negative" target="pizza" to="85"/>
#  <Opinion category="FOOD#QUALITY" from="122" polarity="negative" target="crust" to="127"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1119578:3">
#  <text>A big disappointment, all around.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1123262:0">
#  <text>I think I've had some the best meals of my life at minnow.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="31" polarity="positive" target="meals" to="36"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1123262:1">
#  <text>The seafood is amazing, there's a good wine list, and the ever-changing menu always offers some great surprises.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="seafood" to="11"/>
#  <Opinion category="DRINKS#STYLE_OPTIONS" from="39" polarity="positive" target="wine list" to="48"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="72" polarity="positive" target="menu" to="76"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1123262:2">
#  <text>The combination of super-fresh ingredients in the dishes are unusual but really delicious.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="31" polarity="positive" target="ingredients" to="42"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1123262:3">
#  <text>Worth the trip from Manhattan.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1125006:0">
#  <text>Was there Friday night.</text>
#  </sentence>,
#  <sentence id="1125006:1">
#  <text>Best Pastrami I ever had and great portion without being ridiculous.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="5" polarity="positive" target="Pastrami" to="13"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="35" polarity="positive" target="portion" to="42"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1125006:2">
#  <text>And I've been to many NYC delis.</text>
#  </sentence>,
#  <sentence id="1125006:3">
#  <text>My wife had the fried shrimp which are huge and loved it.</text>
#  <Opinions>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="16" polarity="positive" target="fried shrimp" to="28"/>
#  <Opinion category="FOOD#QUALITY" from="16" polarity="positive" target="fried shrimp" to="28"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="1125006:4">
#  <text>Price no more than a Jersey deli but way better.</text>
#  </sentence>,
#  <sentence id="1125284:0">
#  <text>As a Japanese native, I've lived in the Tristate area for over 8 years, but I was just so amazed at this place.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="105" polarity="positive" target="place" to="110"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1125284:1">
#  <text>This place is the most Japanese it can ever get.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="5" polarity="positive" target="place" to="10"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1125284:2">
#  <text>The signs, the specials menus, food, and even all the waitstaff are ALL TOTALLY Japanese.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="4" polarity="positive" target="signs" to="9"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="15" polarity="positive" target="specials menus" to="29"/>
#  <Opinion category="FOOD#QUALITY" from="31" polarity="positive" target="food" to="35"/>
#  <Opinion category="SERVICE#GENERAL" from="54" polarity="positive" target="waitstaff" to="63"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1125284:3">
#  <text>This place is worth an one-hour drive.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="5" polarity="positive" target="place" to="10"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1125284:4">
#  <text>I am so coming back here again, as much as I can.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1126814:0">
#  <text>Leon is an East Village gem: casual but hip, with well prepared basic French bistro fare, good specials, a warm and lively atmosphere.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="Leon" to="4"/>
#  <Opinion category="AMBIENCE#GENERAL" from="0" polarity="positive" target="Leon" to="4"/>
#  <Opinion category="FOOD#QUALITY" from="95" polarity="positive" target="specials" to="103"/>
#  <Opinion category="AMBIENCE#GENERAL" from="123" polarity="positive" target="atmosphere" to="133"/>
#  <Opinion category="FOOD#QUALITY" from="70" polarity="positive" target="French bistro fare" to="88"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1126814:1">
#  <text>My wife and I always enjoy the young, not always well trained but nevertheless friendly, staff, all of whom have a story.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="89" polarity="positive" target="staff" to="94"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1126814:2">
#  <text>Sit outside in the warm weather; inside for cozy winter.</text>
#  </sentence>,
#  <sentence id="1126814:3">
#  <text>Decent wine at reasonable prices.</text>
#  <Opinions>
#  <Opinion category="DRINKS#QUALITY" from="7" polarity="neutral" target="wine" to="11"/>
#  <Opinion category="DRINKS#PRICES" from="7" polarity="positive" target="wine" to="11"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1126814:4">
#  <text>Have been dozens of times and never failed to enjoy the experience.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1126814:5">
#  <text>Our teenage kids love it, too.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1126886:0">
#  <text>Everytime I decide to try another place on the UES, I get angry that I didn't just go to Zucchero Pomodori.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="89" polarity="positive" target="Zucchero Pomodori" to="106"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1126886:1">
#  <text>This is by far my favorite place in the neighborhood.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="27" polarity="positive" target="place" to="32"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1126886:2">
#  <text>The service is excellent, the decor is great, and the food is delicious and comes in large portions.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="positive" target="service" to="11"/>
#  <Opinion category="AMBIENCE#GENERAL" from="30" polarity="positive" target="decor" to="35"/>
#  <Opinion category="FOOD#QUALITY" from="54" polarity="positive" target="food" to="58"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="91" polarity="positive" target="portions" to="99"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="1126886:3">
#  <text>You'll pay at least double at any other Italian restaurant in the city, and most still don't compare.</text>
#  </sentence>,
#  <sentence id="1126886:4">
#  <text>I'm partial to the Gnocchi.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="19" polarity="positive" target="Gnocchi" to="26"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1131595:0">
#  <text>This place is incredibly tiny.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="5" polarity="negative" target="place" to="10"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1131595:1">
#  <text>They refuse to seat parties of 3 or more on weekends.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1131595:2">
#  <text>The hostess is rude to the point of being offensive.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="negative" target="hostess" to="11"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1131595:3">
#  <text>The food was bland oily.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="negative" target="food" to="8"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1131595:4">
#  <text>I just don't understand all the hype...</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1138996:0">
#  <text>We went to Ino for Valentines.</text>
#  </sentence>,
#  <sentence id="1138996:1">
#  <text>We have been to this place many times, and always have great food, wine, and service.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="61" polarity="positive" target="food" to="65"/>
#  <Opinion category="DRINKS#QUALITY" from="67" polarity="positive" target="wine" to="71"/>
#  <Opinion category="SERVICE#GENERAL" from="77" polarity="positive" target="service" to="84"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1138996:2">
#  <text>We were worried we would have trouble getting in, but somehow managed to have a short wait.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="86" polarity="positive" target="wait" to="90"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1138996:3">
#  <text>As always we had a great glass of wine while we waited.</text>
#  <Opinions>
#  <Opinion category="DRINKS#QUALITY" from="25" polarity="positive" target="glass of wine" to="38"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1138996:4">
#  <text>When we sat, we got great and fast service.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="35" polarity="positive" target="service" to="42"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1138996:5">
#  <text>The people that work there are always so friendly you forget you are in New York sometimes.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="positive" target="people" to="10"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1138996:6">
#  <text>Make sure you try this place as often as you can.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="23" polarity="positive" target="place" to="28"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1145510:0">
#  <text>This is a fun restaurant to go to.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="14" polarity="positive" target="restaurant" to="24"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1145510:1">
#  <text>The pizza is yummy and I like the atmoshpere.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="pizza" to="9"/>
#  <Opinion category="AMBIENCE#GENERAL" from="34" polarity="positive" target="atmoshpere" to="44"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1145510:2">
#  <text>But the pizza is way to expensive.</text>
#  <Opinions>
#  <Opinion category="FOOD#PRICES" from="8" polarity="negative" target="pizza" to="13"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1145510:3">
#  <text>A large is $20, and toppings are about $3 each.</text>
#  <Opinions>
#  <Opinion category="FOOD#PRICES" from="0" polarity="negative" target="NULL" to="0"/>
#  <Opinion category="FOOD#PRICES" from="20" polarity="negative" target="toppings" to="28"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1147082:0">
#  <text>I went there for lunch and it was not as good as I expected from the reviews I read.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="17" polarity="negative" target="lunch" to="22"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1147082:1">
#  <text>Sauce was watery and the food didn't have much flavor.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="negative" target="Sauce" to="5"/>
#  <Opinion category="FOOD#QUALITY" from="25" polarity="negative" target="food" to="29"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="1147082:2">
#  <text>If you like the food and the value you get from some of Chinatown restaurants, this is not the place for you.</text>
#  </sentence>,
#  <sentence id="1147082:3">
#  <text>I don't think I would go again.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1147211:0">
#  <text>This place is great.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="5" polarity="positive" target="place" to="10"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1147211:1">
#  <text>I had a huge group for my birthday and we were well taken care of.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1147211:2">
#  <text>The waitress was very patient with us and the food is phenomenal!</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="positive" target="waitress" to="12"/>
#  <Opinion category="FOOD#QUALITY" from="46" polarity="positive" target="food" to="50"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1147211:3">
#  <text>Service was prompt, friendly and great.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="Service" to="7"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1147211:4">
#  <text>Slightly on the pricey side but worth it!</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#PRICES" from="0" polarity="negative" target="NULL" to="0"/>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1153034:0">
#  <text>Great pizza and fantastic service.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="6" polarity="positive" target="pizza" to="11"/>
#  <Opinion category="SERVICE#GENERAL" from="26" polarity="positive" target="service" to="33"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1153034:1">
#  <text>There was a small wait, but shorter than I expected.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="18" polarity="positive" target="wait" to="22"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1153034:2">
#  <text>Located at the end of a magnificent block.</text>
#  <Opinions>
#  <Opinion category="LOCATION#GENERAL" from="36" polarity="positive" target="block" to="41"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1153034:3">
#  <text>Very cozy and warm inside.....</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1153034:4">
#  <text>I will be back!</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1154550:0">
#  <text>This is the best sushi in new york city - hands down.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="17" polarity="positive" target="sushi" to="22"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1154550:1">
#  <text>The place is small and cramped but the food is fantastic.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="4" polarity="negative" target="place" to="9"/>
#  <Opinion category="FOOD#QUALITY" from="39" polarity="positive" target="food" to="43"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1154550:2">
#  <text>Get the tuna of gari.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="8" polarity="positive" target="tuna of gari" to="20"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="1154550:3">
#  <text>The one on the east side is much better than the one on the west side.</text>
#  </sentence>,
#  <sentence id="1162037:0">
#  <text>Planet Thailand has always been a hit with me , I go there usually for the sushi, which is great , the thai food is excellent too .</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="75" polarity="positive" target="sushi" to="80"/>
#  <Opinion category="FOOD#QUALITY" from="103" polarity="positive" target="thai food" to="112"/>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="Planet Thailand" to="15"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1162037:1">
#  <text>With the great variety on the menu , I eat here often and never get bored .</text>
#  <Opinions>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="30" polarity="positive" target="menu" to="34"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1162037:2">
#  <text>The atmosphere isn't the greatest , but I suppose that's how they keep the prices down .</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="4" polarity="neutral" target="atmosphere" to="14"/>
#  <Opinion category="RESTAURANT#PRICES" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1162037:3">
#  <text>It's all about the food !!</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="19" polarity="positive" target="food" to="23"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1167434:0">
#  <text>I went there with my friend last saturday.</text>
#  </sentence>,
#  <sentence id="1167434:1">
#  <text>first it took us a long time to find the place.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="41" polarity="negative" target="place" to="46"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1167434:2">
#  <text>we were tired and cold when we got to the restaurant, then we sat down to begin ordering appetizers.</text>
#  </sentence>,
#  <sentence id="1167434:3">
#  <text>but when we looked at the menu, there weren't a lot of choices, most of them were dumplings in the appetizer section.</text>
#  <Opinions>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="26" polarity="negative" target="menu" to="30"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1167434:4">
#  <text>then we ordered a dinosaur rolls and white tuna sashimi.</text>
#  </sentence>,
#  <sentence id="1167434:5">
#  <text>those rolls were big, but not good and sashimi wasn't fresh.</text>
#  <Opinions>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="6" polarity="neutral" target="rolls" to="11"/>
#  <Opinion category="FOOD#QUALITY" from="6" polarity="negative" target="rolls" to="11"/>
#  <Opinion category="FOOD#QUALITY" from="39" polarity="negative" target="sashimi" to="46"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1167434:6">
#  <text>they were dry and disgusting, i didn't even finish my first piece.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1175958:0">
#  <text>Hurley's is like Cheers where everyone knows your name and they are ACTUALLY glad you came.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1175958:1">
#  <text>Try the crunchy tuna, it is to die for.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="8" polarity="positive" target="crunchy tuna" to="20"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1175958:2">
#  <text>Try everything for that matter, it is all good.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1175958:3">
#  <text>I have been going there since it opened and I can't get enough.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1189674:0">
#  <text>First went here to enjoy their garden terrace.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="31" polarity="positive" target="garden terrace" to="45"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1189674:1">
#  <text>The food was amazing, and the service was prompt and helpful, but not over-bearing or rushed.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="food" to="8"/>
#  <Opinion category="SERVICE#GENERAL" from="30" polarity="positive" target="service" to="37"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1189674:2">
#  <text>The Steak Tartare is a great bet, they fix it for you at the table.</text>
#  <Opinions>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="4" polarity="positive" target="Steak Tartare" to="17"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1189674:3">
#  <text>Admittedly some nights inside the restaurant were rather warm, but the open kitchen is part of the charm.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="71" polarity="positive" target="open kitchen" to="83"/>
#  <Opinion category="AMBIENCE#GENERAL" from="34" polarity="negative" target="restaurant" to="44"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1189674:4">
#  <text>Great wine selection, Gigondas is worth the price, and the house champagne is a great value.</text>
#  <Opinions>
#  <Opinion category="DRINKS#STYLE_OPTIONS" from="6" polarity="positive" target="wine selection" to="20"/>
#  <Opinion category="DRINKS#QUALITY" from="22" polarity="positive" target="Gigondas" to="30"/>
#  <Opinion category="DRINKS#PRICES" from="59" polarity="positive" target="house champagne" to="74"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="1189674:5">
#  <text>It may be a bit packed on weekends, but the vibe is good and it is the best French food you will find in the area.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="0" polarity="neutral" target="NULL" to="0"/>
#  <Opinion category="AMBIENCE#GENERAL" from="44" polarity="positive" target="vibe" to="48"/>
# ...
#  </Opinions>
#  </sentence>,
#  <sentence id="476473:3">
#  <text>Open late (well as late as I ever got there and I'm a night person)</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="483111:0">
#  <text>Winnie and her staff are the best crew you can find serving you.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="15" polarity="positive" target="staff" to="20"/>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="Winnie" to="6"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="483111:1">
#  <text>The food is reliable and the price is moderate.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="food" to="8"/>
#  <Opinion category="RESTAURANT#PRICES" from="0" polarity="neutral" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="483111:2">
#  <text>What more can you ask for?</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485026:0">
#  <text>For authentic Thai food, look no further than Toons.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="14" polarity="positive" target="Thai food" to="23"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="485026:1">
#  <text>Ive been to many Thai restaurants in Manhattan before, and Toons is by far the best Thai food Ive had (except for my mom's of course).</text>
#  </sentence>,
#  <sentence id="485026:2">
#  <text>Try the Pad Thai, or sample anything on the appetizer menu...they're all delicious.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="8" polarity="positive" target="Pad Thai" to="16"/>
#  <Opinion category="FOOD#QUALITY" from="44" polarity="positive" target="appetizer menu" to="58"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485767:0">
#  <text>Everything about this restaurant was special.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="22" polarity="positive" target="restaurant" to="32"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485767:1">
#  <text>The service was attentive, yet discreet.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="positive" target="service" to="11"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485767:2">
#  <text>The flavors robust and subtle.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485767:3">
#  <text>The brioche and lollies as party favors is a cute and sweet touch to a most memorable meal.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="brioche and lollies" to="23"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485767:4">
#  <text>I'm saving up for my next visit.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485966:0">
#  <text>I went there in late afternoon for some bite size food and refleshment with my date.</text>
#  </sentence>,
#  <sentence id="485966:1">
#  <text>The place was quiet and delightful.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="4" polarity="positive" target="place" to="9"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485966:2">
#  <text>Service was good and food is wonderful.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="0" polarity="positive" target="Service" to="7"/>
#  <Opinion category="FOOD#QUALITY" from="21" polarity="positive" target="food" to="25"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485966:3">
#  <text>I did not try the caviar but I tried their salmon and crab salad (they are all good)  </text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="43" polarity="positive" target="salmon" to="49"/>
#  <Opinion category="FOOD#QUALITY" from="54" polarity="positive" target="crab salad" to="64"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="485966:4">
#  <text>It is definitely a good spot for snacks and chat.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="24" polarity="positive" target="spot" to="28"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="490565:0">
#  <text>As a retired hipster, I can say with some degree of certainty that for the last year Lucky Strike has been the best laid-back late night in the city.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="85" polarity="positive" target="Lucky Strike" to="97"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="490565:1">
#  <text>The wait staff is pleasant, fun, and for the most part gorgeous (in the wonderful aesthetic beautification way, not in that she's-way-cuter-than-me-that-b@#$* way).</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="positive" target="wait staff" to="14"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="490565:2">
#  <text>The food is yummy, especially their cooked-to-perfection mussels in spicy tomato sauce and their shoestring crispy fries.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="food" to="8"/>
#  <Opinion category="FOOD#QUALITY" from="57" polarity="positive" target="mussels in spicy tomato sauce" to="86"/>
#  <Opinion category="FOOD#QUALITY" from="115" polarity="positive" target="fries" to="120"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="490565:3">
#  <text>But the best part about LS is the late night atmosphere, delightfully free of the BTs.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="34" polarity="positive" target="late night atmosphere" to="55"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="490565:4">
#  <text>You can get a completely delish martini in a glass (that's about 2 1/2 drinks) for $8.50 (I recommend the Vanilla Shanty, mmmm!) in a great homey setting with great music.</text>
#  <Opinions>
#  <Opinion category="DRINKS#QUALITY" from="32" polarity="positive" target="martini" to="39"/>
#  <Opinion category="DRINKS#STYLE_OPTIONS" from="32" polarity="positive" target="martini" to="39"/>
#  <Opinion category="DRINKS#PRICES" from="32" polarity="positive" target="martini" to="39"/>
#  <Opinion category="DRINKS#QUALITY" from="106" polarity="positive" target="Vanilla Shanty" to="120"/>
#  <Opinion category="AMBIENCE#GENERAL" from="146" polarity="positive" target="setting" to="153"/>
#  <Opinion category="AMBIENCE#GENERAL" from="165" polarity="positive" target="music" to="170"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="490565:5">
#  <text>The in-house lady DJ on Saturday nights has outrageously good taste in music, and moreover, takes requests.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="4" polarity="positive" target="in-house lady DJ" to="20"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="490565:6">
#  <text>You can't go wrong with this place.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="29" polarity="positive" target="place" to="34"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="493013:0">
#  <text>Suan is a great place that I often take my friends (classmates) too.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="Suan" to="4"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="493013:1">
#  <text>Its location is good and the fact that Hutner College is near and their prices are very reasonable, makes students go back to Suan again and again.</text>
#  <Opinions>
#  <Opinion category="LOCATION#GENERAL" from="4" polarity="positive" target="location" to="12"/>
#  <Opinion category="RESTAURANT#PRICES" from="126" polarity="positive" target="Suan" to="130"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="493013:2">
#  <text>I LOVE their Thai</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="13" polarity="positive" target="Thai" to="17"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="493013:3">
#  <text>noodles with shrimp and chicken and coconut juice is the MUST!</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="noodles with shrimp and chicken and coconut juice" to="49"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="493013:4">
#  <text>I was in love with Pongsri on 48th, but compared to Suan it is slow in service and overpriced.</text>
#  </sentence>,
#  <sentence id="493013:5">
#  <text>I will go back to Suan soon!</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="18" polarity="positive" target="Suan" to="22"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="493013:6">
#  <text>In summer-eat outside on a terrace (another great feature of Suan)!!!</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="27" polarity="positive" target="terrace" to="34"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="493514:0">
#  <text>I cannot imagine a friendlier staff working in a restaurant.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="30" polarity="positive" target="staff" to="35"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="493514:1">
#  <text>I cannot imagine better Indian food in all of the city.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="24" polarity="positive" target="Indian food" to="35"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="493514:2">
#  <text>I cannot imagine you not rushing out to eat there.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="494850:0">
#  <text>This restaurant used to be our regular Thursday night dinner location.</text>
#  </sentence>,
#  <sentence id="494850:1">
#  <text>During the course of the past 3 months, the chef and staff changed and it was not for the better.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="44" polarity="negative" target="chef" to="48"/>
#  <Opinion category="SERVICE#GENERAL" from="53" polarity="negative" target="staff" to="58"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="494850:2">
#  <text>I wish they would change back to what it was before.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="494850:3">
#  <text>The food now is inconsistent.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="negative" target="food" to="8"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="496132:0">
#  <text>This is the kind of place you'd like to take all your friends to and still keep a secret.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="20" polarity="positive" target="place" to="25"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="496132:1">
#  <text>The setting is casual and romantic.</text>
#  <Opinions>
#  <Opinion category="AMBIENCE#GENERAL" from="4" polarity="positive" target="setting" to="11"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="496132:2">
#  <text>Prices are very good.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#PRICES" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="496132:3">
#  <text>The food is excellent! </text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="food" to="8"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="496132:4">
#  <text>if you're daring, try the balsamic vinegar over icecream, it's wonderful!</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="26" polarity="positive" target="balsamic vinegar over icecream" to="56"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="498657:0">
#  <text>Do not get the Go Go Hamburgers, no matter what the reviews say.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="15" polarity="negative" target="Go Go Hamburgers" to="31"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="498657:1">
#  <text>They were such a rip-off ($8.95 for four small meat patties in steamed buns) and not worth trying.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="negative" target="NULL" to="0"/>
#  <Opinion category="FOOD#STYLE_OPTIONS" from="0" polarity="negative" target="NULL" to="0"/>
#  <Opinion category="FOOD#PRICES" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="498657:2">
#  <text>The rest of the dim sum, though pricey by Chinatown standards, is worth it.</text>
#  <Opinions>
#  <Opinion category="FOOD#PRICES" from="16" polarity="negative" target="dim sum" to="23"/>
#  <Opinion category="FOOD#QUALITY" from="16" polarity="positive" target="dim sum" to="23"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="498657:3">
#  <text>Steamed fresh so brought hot hot hot to your table.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="498657:4">
#  <text>The wait here is long for dim sum, but if you don't like sharing tables or if the typical raucous dim sum atmosphere is not your gig, this is a sleek (for Chinatown) alternative.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="negative" target="wait" to="8"/>
#  <Opinion category="AMBIENCE#GENERAL" from="106" polarity="negative" target="atmosphere" to="116"/>
#  <Opinion category="RESTAURANT#MISCELLANEOUS" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="498657:5">
#  <text>A few tips: skip the turnip cake, roast pork buns and egg custards.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="21" polarity="negative" target="turnip cake" to="32"/>
#  <Opinion category="FOOD#QUALITY" from="34" polarity="negative" target="roast pork buns" to="49"/>
#  <Opinion category="FOOD#QUALITY" from="54" polarity="negative" target="egg custards" to="66"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="498657:6">
#  <text>These are overpriced and you can get better just around the corner:</text>
#  <Opinions>
#  <Opinion category="FOOD#PRICES" from="0" polarity="negative" target="NULL" to="0"/>
#  <Opinion category="FOOD#QUALITY" from="0" polarity="negative" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="498657:7">
#  <text>(1) turnip cakes at the little kiosk on east side of Mott St. just south of bayard</text>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="498657:8">
#  <text>(2) egg custards and pork buns at either bakery on west side of Mott street just south of Canal.</text>
#  </sentence>,
#  <sentence id="503807:0">
#  <text>After passing by this restaurant for sometime I finally decided to go in and have dinner.</text>
#  </sentence>,
#  <sentence id="503807:1">
#  <text>I was pleasantly suprised.</text>
#  <Opinions>
#  <Opinion category="RESTAURANT#GENERAL" from="0" polarity="positive" target="NULL" to="0"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="503807:2">
#  <text>The food was exceptional.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="4" polarity="positive" target="food" to="8"/>
#  </Opinions>
#  </sentence>,
#  <sentence OutOfScope="TRUE" id="503807:3">
#  <text>The menu consisted of standard brassiere food, better then places like Balthazar etc.</text>
#  </sentence>,
#  <sentence id="503807:4">
#  <text>I choose to go with one of the special, the braised lamb shank in red wine, which was excellent.</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="44" polarity="positive" target="braised lamb shank in red wine" to="74"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="503807:5">
#  <text>The service was friendly and the atmosphere was casual.</text>
#  <Opinions>
#  <Opinion category="SERVICE#GENERAL" from="4" polarity="positive" target="service" to="11"/>
#  <Opinion category="AMBIENCE#GENERAL" from="33" polarity="neutral" target="atmosphere" to="43"/>
#  </Opinions>
#  </sentence>,
#  <sentence id="503807:6">
#  <text>The restaurant is a bit noisy but that is something that can be overlooked once you sit down and enjoy a great meal</text>
#  <Opinions>
#  <Opinion category="FOOD#QUALITY" from="111" polarity="positive" target="meal" to="115"/>
#  <Opinion category="AMBIENCE#GENERAL" from="4" polarity="neutral" target="restaurant" to="14"/>
#  </Opinions>
#  </sentence>,
#  ...]

# %%
def soup2dict(sentence_nodes):
    nkata=[]
    i=0
    for n in sentence_nodes:
        i+=1
        kata={}
        aspect_term=[]
        kata['id']=i
        kata['text']=n.find('text').string
        if n.find('Opinions'):
            for c in n.find('Opinions').contents:
                if c.name=='Opinion':
                    if c['target'] not in aspect_term:
                        aspect_term.append(c['target'])
        kata['aspect']=aspect_term
        nkata.append(kata)
    return(nkata)

# %%
kata = soup2dict(sentence_nodes)
kata
# Out:
# [{'id': 1,
#   'text': 'Judging from previous posts this used to be a good place, but not any longer.',
#   'aspect': ['place']},
#  {'id': 2,
#   'text': 'We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.',
#   'aspect': ['staff']},
#  {'id': 3,
#   'text': 'They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.',
#   'aspect': ['NULL']},
#  {'id': 4,
#   'text': 'The food was lousy - too sweet or too salty and the portions tiny.',
#   'aspect': ['food', 'portions']},
#  {'id': 5,
#   'text': 'After all that, they complained to me about the small tip.',
#   'aspect': ['NULL']},
#  {'id': 6, 'text': 'Avoid this place!', 'aspect': ['place']},
#  {'id': 7,
#   'text': 'I have eaten at Saul, many times, the food is always consistently, outrageously good.',
#   'aspect': ['food']},
#  {'id': 8,
#   'text': 'Saul is the best restaurant on Smith Street and in Brooklyn.',
#   'aspect': ['Saul']},
#  {'id': 9,
#   'text': 'The duck confit is always amazing and the foie gras terrine with figs was out of this world.',
#   'aspect': ['foie gras terrine with figs', 'duck confit']},
#  {'id': 10,
#   'text': 'The wine list is interesting and has many good values.',
#   'aspect': ['wine list']},
#  {'id': 11,
#   'text': 'For the price, you cannot eat this well in Manhattan.',
#   'aspect': ['NULL']},
#  {'id': 12,
#   'text': 'I was very disappointed with this restaurant.',
#   'aspect': ['restaurant']},
#  {'id': 13,
#   'text': 'Ive asked a cart attendant for a lotus leaf wrapped rice and she replied back rice and just walked away.',
#   'aspect': ['cart attendant']},
#  {'id': 14,
#   'text': 'I had to ask her three times before she finally came back with the dish Ive requested.',
#   'aspect': ['NULL']},
#  {'id': 15, 'text': 'Food was okay, nothing great.', 'aspect': ['Food']},
#  {'id': 16,
#   'text': 'Chow fun was dry; pork shu mai was more than usually greasy and had to share a table with loud and rude family. ',
#   'aspect': ['Chow fun', 'pork shu mai', 'NULL']},
#  {'id': 17,
#   'text': 'I/we will never go back to this place again.',
#   'aspect': ['place']},
#  {'id': 18,
#   'text': 'Went on a 3 day oyster binge, with Fish bringing up the closing, and I am so glad this was the place it O trip ended, because it was so great!',
#   'aspect': ['Fish']},
#  {'id': 19,
#   'text': "Service was devine, oysters where a sensual as they come, and the price can't be beat!!!",
#   'aspect': ['Service', 'oysters', 'NULL']},
#  {'id': 20, 'text': "You can't go wrong here.", 'aspect': ['NULL']},
#  {'id': 21,
#   'text': 'Every time in New York I make it a point to visit Restaurant Saul on Smith Street.',
#   'aspect': ['Restaurant Saul']},
#  {'id': 22,
#   'text': 'Everything is always cooked to perfection, the service is excellent, the decor cool and understated.',
#   'aspect': ['NULL', 'service', 'decor']},
#  {'id': 23,
#   'text': 'I had the duck breast special on my last visit and it was incredible.',
#   'aspect': ['duck breast special']},
#  {'id': 24, 'text': "Can't wait wait for my next visit.", 'aspect': ['NULL']},
#  {'id': 25,
#   'text': "I had my eyes on this place, promising myself I will one day 'give it a try.' ",
#   'aspect': []},
#  {'id': 26,
#   'text': "And I hate to say this but I doubt I'll ever go back. ",
#   'aspect': ['NULL']},
#  {'id': 27,
#   'text': 'The food is very average...the Thai fusion stuff is a bit too sweet, every thing they serve is too sweet here.',
#   'aspect': ['food', 'Thai fusion stuff', 'NULL']},
#  {'id': 28,
#   'text': 'The only thing I moderately enjoyed was their Grilled Chicken special with Edamame Puree.',
#   'aspect': ['Grilled Chicken special with Edamame Puree']},
#  {'id': 29,
#   'text': "I had never had Edamame pureed before but I thought it was innovative and tasty (could've used a bit more salt).",
#   'aspect': ['Edamame pureed']},
#  {'id': 30,
#   'text': "Anyways, if you're in the neighborhood to eat good food, I wouldn't waste my time trying to find something, rather go across the street to Tamari.",
#   'aspect': []},
#  {'id': 31,
#   'text': 'The decor is night tho...but they REALLY need to clean that vent in the ceiling...its quite un-appetizing, and kills your effort to make this place look sleek and modern.',
#   'aspect': ['place', 'decor', 'vent']},
#  {'id': 32,
#   'text': "We ate outside at Haru's Sake bar because Haru's restaurant next door was overflowing.",
#   'aspect': []},
#  {'id': 33, 'text': "What's the difference between the two?", 'aspect': []},
#  {'id': 34,
#   'text': "Their sake list was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!",
#   'aspect': ['sake list', 'NULL']},
#  {'id': 35,
#   'text': 'The spicy tuna roll was unusually good and the rock shrimp tempura was awesome, great appetizer to share!',
#   'aspect': ['spicy tuna roll', 'rock shrimp tempura']},
#  {'id': 36,
#   'text': 'We went around 9:30 on a Friday and it had died down a bit by then so the service was great!',
#   'aspect': ['service']},
#  {'id': 37, 'text': 'we love th pink pony.', 'aspect': ['pink pony']},
#  {'id': 38, 'text': 'THe perfect spot.', 'aspect': ['spot']},
#  {'id': 39, 'text': 'Food-awesome.', 'aspect': ['Food']},
#  {'id': 40, 'text': 'Service- friendly and attentive.', 'aspect': ['Service']},
#  {'id': 41, 'text': 'Ambiance- relaxed and stylish.', 'aspect': ['Ambiance']},
#  {'id': 42,
#   'text': "Don't judge this place prima facie, you have to try it to believe it, a home away from home for the literate heart.",
#   'aspect': ['place']},
#  {'id': 43,
#   'text': 'i have eaten here a handful of times, for no reason besides sheer convenience.',
#   'aspect': []},
#  {'id': 44,
#   'text': '(i hang out, and live, in the neighborhood..) ',
#   'aspect': []},
#  {'id': 45, 'text': 'the food is decent.', 'aspect': ['food']},
#  {'id': 46,
#   'text': "however, it's the service that leaves a bad taste in my mouth.",
#   'aspect': ['service']},
#  {'id': 47,
#   'text': 'i happen to have a policy that goes along with a little bit of self-respect, which includes not letting a waiter intimidate me, i.e. make me feel bad asking for trivialities like water, or the check.',
#   'aspect': ['waiter']},
#  {'id': 48,
#   'text': "i know, you were too busy showing off your vintage tee shirt and looking bored, but my agenda is i'm here to eat and enjoy the company of friends, seeking a pleasant experience.",
#   'aspect': ['NULL']},
#  {'id': 49,
#   'text': "well, i didn't find it there, and trust, i have told everyone i can think of about my experience. ",
#   'aspect': ['NULL']},
#  {'id': 50,
#   'text': 'the last time i walked by it looked pretty empty. hmmm.',
#   'aspect': ['NULL']},
#  {'id': 51,
#   'text': 'This place has got to be the best japanese restaurant in the new york area.',
#   'aspect': ['place']},
#  {'id': 52, 'text': 'I had a great experience.', 'aspect': ['NULL']},
#  {'id': 53, 'text': 'Food is great.', 'aspect': ['Food']},
#  {'id': 54, 'text': 'Service is top notch.', 'aspect': ['Service']},
#  {'id': 55,
#   'text': 'I have been going back again and again.',
#   'aspect': ['NULL']},
#  {'id': 56,
#   'text': 'I tend to judge a sushi restaurant by its sea urchin, which was heavenly at sushi rose.',
#   'aspect': ['sea urchin']},
#  {'id': 57,
#   'text': 'It melted in my little mouth and the perfect consistency-not too fishy, creamy, and slightly buttery.',
#   'aspect': ['NULL']},
#  {'id': 58,
#   'text': 'The sushi seemed pretty fresh and was adequately proportioned.',
#   'aspect': ['sushi']},
#  {'id': 59,
#   'text': "The rice to fish ration was also good--they didn't try to overpack the rice.",
#   'aspect': ['rice to fish ration']},
#  {'id': 60,
#   'text': 'We took advanatage of the half price sushi deal on saturday so it was well worth it.',
#   'aspect': ['half price sushi deal']},
#  {'id': 61,
#   'text': 'I went to this restaurant with a woman that I met recently.',
#   'aspect': []},
#  {'id': 62,
#   'text': 'She lives nearby but had never gone to this establishment thinking that it might be too touristy.',
#   'aspect': []},
#  {'id': 63,
#   'text': 'Surprisingly nothing could be further from the truth.',
#   'aspect': ['NULL']},
#  {'id': 64,
#   'text': 'In the evening, this place attracted a well dressed, with it, NY crowd.',
#   'aspect': ['crowd']},
#  {'id': 65,
#   'text': 'The food was well prepared and the service impecable.',
#   'aspect': ['food', 'service']},
#  {'id': 66, 'text': "I'm going back.", 'aspect': ['NULL']},
#  {'id': 67,
#   'text': 'Having hunted around for a quiet, romantic, yet not hideously expensive restaurant I stumbled across reviews for La Lanterna and gave it a shot.',
#   'aspect': []},
#  {'id': 68,
#   'text': "Quite simply it's like stepping out of Manhattan and into a haven of tranquility.",
#   'aspect': ['NULL']},
#  {'id': 69,
#   'text': 'The service was attentive, yet unimposing, the food was far better than many notorious restaurants in Midtown and the wine list is extensive and well priced.',
#   'aspect': []},
#  {'id': 70,
#   'text': 'The Prix Fixe menu is worth every penny and you get more than enough (both in quantity AND quality).',
#   'aspect': ['Prix Fixe menu']},
#  {'id': 71,
#   'text': 'I will be going back and heartily recommend it!',
#   'aspect': ['NULL']},
#  {'id': 72,
#   'text': "I've had the lunch buffet at Chennai a couple of times, when I have been in the neighborhood.",
#   'aspect': []},
#  {'id': 73, 'text': 'It is terrific, as is the value.', 'aspect': ['NULL']},
#  {'id': 74,
#   'text': '$6 and there is much tasty food, all of it fresh and continually refilled.',
#   'aspect': ['food']},
#  {'id': 75,
#   'text': 'I am not a vegetarian but, almost all the dishes were great.',
#   'aspect': ['dishes']},
#  {'id': 76,
#   'text': 'Frankly, when you compare what you can have here for lunch, versus McDs or so many other sandwich shops in the city, there is no comparison.',
#   'aspect': []},
#  {'id': 77, 'text': 'Go hungry and enjoy.', 'aspect': ['NULL']},
#  {'id': 78,
#   'text': 'The food here is rather good, but only if you like to wait for it.',
#   'aspect': ['food', 'NULL']},
#  {'id': 79,
#   'text': 'I like the somosas, chai, and the chole, but the dhosas and dhal were kinda dissapointing.',
#   'aspect': ['somosas', 'chai', 'chole', 'dhosas', 'dhal']},
#  {'id': 80,
#   'text': "The service varys from day to day- sometimes they're very nice, and sometimes not.",
#   'aspect': ['service']},
#  {'id': 81,
#   'text': 'The kitchen however, is almost always slow.',
#   'aspect': ['kitchen']},
#  {'id': 82,
#   'text': "Also, specify if you like your food spicy- its rather bland if you don't.",
#   'aspect': ['food']},
#  {'id': 83,
#   'text': 'The ambience is pretty and nice for conversation, so a casual lunch here would probably be best.',
#   'aspect': ['ambience', 'NULL']},
#  {'id': 84,
#   'text': 'Just went here for my girlfriends 23rd bday.',
#   'aspect': []},
#  {'id': 85,
#   'text': "If you've ever been along the river in Weehawken you have an idea of the top of view the chart house has to offer.",
#   'aspect': ['view']},
#  {'id': 86,
#   'text': 'Add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening.',
#   'aspect': ['service', 'food']},
#  {'id': 87,
#   'text': 'The lava cake dessert was incredible and I recommend it.',
#   'aspect': ['lava cake dessert']},
#  {'id': 88,
#   'text': "Once you step into Cosette, you're miraculously in a small, off-the-beaten path Parisian bistro.",
#   'aspect': ['Cosette']},
#  {'id': 89,
#   'text': 'This tiny restaurant is as cozy as it gets, with that certain Parisian flair.',
#   'aspect': ['restaurant']},
#  {'id': 90,
#   'text': 'The food was average to above-average; the French Onion soup filling yet not overly impressive, and the desserts not brilliant in any way.',
#   'aspect': ['food', 'French Onion soup', 'desserts']},
#  {'id': 91,
#   'text': 'However, go for the ambience, and consider the food just a companion for a trip across the world!',
#   'aspect': ['ambience', 'food']},
#  {'id': 92,
#   'text': 'I have never eaten in the restaurant, however, upon reading the reviews I got take out last week.',
#   'aspect': []},
#  {'id': 93, 'text': 'IT WAS HORRIBLE.', 'aspect': ['NULL']},
#  {'id': 94,
#   'text': "The pizza was delivered cold and the cheese wasn't even fully melted!",
#   'aspect': ['pizza', 'cheese']},
#  {'id': 95,
#   'text': 'It looked like shredded cheese partly done - still in strips.',
#   'aspect': ['NULL']},
#  {'id': 96,
#   'text': 'I have eaten at many pizza places around NYC and this is hands down the worst.',
#   'aspect': []},
#  {'id': 97,
#   'text': 'This has got to be one of the most overrated restaurants in Brooklyn.',
#   'aspect': ['NULL']},
#  {'id': 98, 'text': 'The pizza is overpriced and soggy.', 'aspect': ['pizza']},
#  {'id': 99,
#   'text': "Yes, they use fancy ingredients, but even fancy ingredients don't make for good pizza unless someone knows how to get the crust right.",
#   'aspect': ['ingredients', 'pizza', 'crust']},
#  {'id': 100, 'text': 'A big disappointment, all around.', 'aspect': ['NULL']},
#  {'id': 101,
#   'text': "I think I've had some the best meals of my life at minnow.",
#   'aspect': ['meals']},
#  {'id': 102,
#   'text': "The seafood is amazing, there's a good wine list, and the ever-changing menu always offers some great surprises.",
#   'aspect': ['seafood', 'wine list', 'menu']},
#  {'id': 103,
#   'text': 'The combination of super-fresh ingredients in the dishes are unusual but really delicious.',
#   'aspect': ['ingredients']},
#  {'id': 104, 'text': 'Worth the trip from Manhattan.', 'aspect': ['NULL']},
#  {'id': 105, 'text': 'Was there Friday night.', 'aspect': []},
#  {'id': 106,
#   'text': 'Best Pastrami I ever had and great portion without being ridiculous.',
#   'aspect': ['Pastrami', 'portion']},
#  {'id': 107, 'text': "And I've been to many NYC delis.", 'aspect': []},
#  {'id': 108,
#   'text': 'My wife had the fried shrimp which are huge and loved it.',
#   'aspect': ['fried shrimp']},
#  {'id': 109,
#   'text': 'Price no more than a Jersey deli but way better.',
#   'aspect': []},
#  {'id': 110,
#   'text': "As a Japanese native, I've lived in the Tristate area for over 8 years, but I was just so amazed at this place.",
#   'aspect': ['place']},
#  {'id': 111,
#   'text': 'This place is the most Japanese it can ever get.',
#   'aspect': ['place']},
#  {'id': 112,
#   'text': 'The signs, the specials menus, food, and even all the waitstaff are ALL TOTALLY Japanese.',
#   'aspect': ['signs', 'specials menus', 'food', 'waitstaff']},
#  {'id': 113,
#   'text': 'This place is worth an one-hour drive.',
#   'aspect': ['place']},
#  {'id': 114,
#   'text': 'I am so coming back here again, as much as I can.',
#   'aspect': ['NULL']},
#  {'id': 115,
#   'text': 'Leon is an East Village gem: casual but hip, with well prepared basic French bistro fare, good specials, a warm and lively atmosphere.',
#   'aspect': ['Leon', 'specials', 'atmosphere', 'French bistro fare']},
#  {'id': 116,
#   'text': 'My wife and I always enjoy the young, not always well trained but nevertheless friendly, staff, all of whom have a story.',
#   'aspect': ['staff']},
#  {'id': 117,
#   'text': 'Sit outside in the warm weather; inside for cozy winter.',
#   'aspect': []},
#  {'id': 118, 'text': 'Decent wine at reasonable prices.', 'aspect': ['wine']},
#  {'id': 119,
#   'text': 'Have been dozens of times and never failed to enjoy the experience.',
#   'aspect': ['NULL']},
#  {'id': 120, 'text': 'Our teenage kids love it, too.', 'aspect': ['NULL']},
#  {'id': 121,
#   'text': "Everytime I decide to try another place on the UES, I get angry that I didn't just go to Zucchero Pomodori.",
#   'aspect': ['Zucchero Pomodori']},
#  {'id': 122,
#   'text': 'This is by far my favorite place in the neighborhood.',
#   'aspect': ['place']},
#  {'id': 123,
#   'text': 'The service is excellent, the decor is great, and the food is delicious and comes in large portions.',
#   'aspect': ['service', 'decor', 'food', 'portions']},
#  {'id': 124,
#   'text': "You'll pay at least double at any other Italian restaurant in the city, and most still don't compare.",
#   'aspect': []},
#  {'id': 125, 'text': "I'm partial to the Gnocchi.", 'aspect': ['Gnocchi']},
#  {'id': 126, 'text': 'This place is incredibly tiny.', 'aspect': ['place']},
#  {'id': 127,
#   'text': 'They refuse to seat parties of 3 or more on weekends.',
#   'aspect': ['NULL']},
#  {'id': 128,
#   'text': 'The hostess is rude to the point of being offensive.',
#   'aspect': ['hostess']},
#  {'id': 129, 'text': 'The food was bland oily.', 'aspect': ['food']},
#  {'id': 130,
#   'text': "I just don't understand all the hype...",
#   'aspect': ['NULL']},
#  {'id': 131, 'text': 'We went to Ino for Valentines.', 'aspect': []},
#  {'id': 132,
#   'text': 'We have been to this place many times, and always have great food, wine, and service.',
#   'aspect': ['food', 'wine', 'service']},
#  {'id': 133,
#   'text': 'We were worried we would have trouble getting in, but somehow managed to have a short wait.',
#   'aspect': ['wait']},
#  {'id': 134,
#   'text': 'As always we had a great glass of wine while we waited.',
#   'aspect': ['glass of wine']},
#  {'id': 135,
#   'text': 'When we sat, we got great and fast service.',
#   'aspect': ['service']},
#  {'id': 136,
#   'text': 'The people that work there are always so friendly you forget you are in New York sometimes.',
#   'aspect': ['people']},
#  {'id': 137,
#   'text': 'Make sure you try this place as often as you can.',
#   'aspect': ['place']},
#  {'id': 138,
#   'text': 'This is a fun restaurant to go to.',
#   'aspect': ['restaurant']},
#  {'id': 139,
#   'text': 'The pizza is yummy and I like the atmoshpere.',
#   'aspect': ['pizza', 'atmoshpere']},
#  {'id': 140,
#   'text': 'But the pizza is way to expensive.',
#   'aspect': ['pizza']},
#  {'id': 141,
#   'text': 'A large is $20, and toppings are about $3 each.',
#   'aspect': ['NULL', 'toppings']},
#  {'id': 142,
#   'text': 'I went there for lunch and it was not as good as I expected from the reviews I read.',
#   'aspect': ['lunch']},
#  {'id': 143,
#   'text': "Sauce was watery and the food didn't have much flavor.",
#   'aspect': ['Sauce', 'food']},
#  {'id': 144,
#   'text': 'If you like the food and the value you get from some of Chinatown restaurants, this is not the place for you.',
#   'aspect': []},
#  {'id': 145, 'text': "I don't think I would go again.", 'aspect': ['NULL']},
#  {'id': 146, 'text': 'This place is great.', 'aspect': ['place']},
#  {'id': 147,
#   'text': 'I had a huge group for my birthday and we were well taken care of.',
#   'aspect': ['NULL']},
#  {'id': 148,
#   'text': 'The waitress was very patient with us and the food is phenomenal!',
#   'aspect': ['waitress', 'food']},
#  {'id': 149,
#   'text': 'Service was prompt, friendly and great.',
#   'aspect': ['Service']},
#  {'id': 150,
#   'text': 'Slightly on the pricey side but worth it!',
#   'aspect': ['NULL']},
#  {'id': 151,
#   'text': 'Great pizza and fantastic service.',
#   'aspect': ['pizza', 'service']},
#  {'id': 152,
#   'text': 'There was a small wait, but shorter than I expected.',
#   'aspect': ['wait']},
#  {'id': 153,
#   'text': 'Located at the end of a magnificent block.',
#   'aspect': ['block']},
#  {'id': 154, 'text': 'Very cozy and warm inside.....', 'aspect': ['NULL']},
#  {'id': 155, 'text': 'I will be back!', 'aspect': ['NULL']},
#  {'id': 156,
#   'text': 'This is the best sushi in new york city - hands down.',
#   'aspect': ['sushi']},
#  {'id': 157,
#   'text': 'The place is small and cramped but the food is fantastic.',
#   'aspect': ['place', 'food']},
#  {'id': 158, 'text': 'Get the tuna of gari.', 'aspect': ['tuna of gari']},
#  {'id': 159,
#   'text': 'The one on the east side is much better than the one on the west side.',
#   'aspect': []},
#  {'id': 160,
#   'text': 'Planet Thailand has always been a hit with me , I go there usually for the sushi, which is great , the thai food is excellent too .',
#   'aspect': ['sushi', 'thai food', 'Planet Thailand']},
#  {'id': 161,
#   'text': 'With the great variety on the menu , I eat here often and never get bored .',
#   'aspect': ['menu']},
#  {'id': 162,
#   'text': "The atmosphere isn't the greatest , but I suppose that's how they keep the prices down .",
#   'aspect': ['atmosphere', 'NULL']},
#  {'id': 163, 'text': "It's all about the food !!", 'aspect': ['food']},
#  {'id': 164,
#   'text': 'I went there with my friend last saturday.',
#   'aspect': []},
#  {'id': 165,
#   'text': 'first it took us a long time to find the place.',
#   'aspect': ['place']},
#  {'id': 166,
#   'text': 'we were tired and cold when we got to the restaurant, then we sat down to begin ordering appetizers.',
#   'aspect': []},
#  {'id': 167,
#   'text': "but when we looked at the menu, there weren't a lot of choices, most of them were dumplings in the appetizer section.",
#   'aspect': ['menu']},
#  {'id': 168,
#   'text': 'then we ordered a dinosaur rolls and white tuna sashimi.',
#   'aspect': []},
#  {'id': 169,
#   'text': "those rolls were big, but not good and sashimi wasn't fresh.",
#   'aspect': ['rolls', 'sashimi']},
#  {'id': 170,
#   'text': "they were dry and disgusting, i didn't even finish my first piece.",
#   'aspect': ['NULL']},
#  {'id': 171,
#   'text': "Hurley's is like Cheers where everyone knows your name and they are ACTUALLY glad you came.",
#   'aspect': ['NULL']},
#  {'id': 172,
#   'text': 'Try the crunchy tuna, it is to die for.',
#   'aspect': ['crunchy tuna']},
#  {'id': 173,
#   'text': 'Try everything for that matter, it is all good.',
#   'aspect': ['NULL']},
#  {'id': 174,
#   'text': "I have been going there since it opened and I can't get enough.",
#   'aspect': ['NULL']},
#  {'id': 175,
#   'text': 'First went here to enjoy their garden terrace.',
#   'aspect': ['garden terrace']},
#  {'id': 176,
#   'text': 'The food was amazing, and the service was prompt and helpful, but not over-bearing or rushed.',
#   'aspect': ['food', 'service']},
#  {'id': 177,
#   'text': 'The Steak Tartare is a great bet, they fix it for you at the table.',
#   'aspect': ['Steak Tartare']},
#  {'id': 178,
#   'text': 'Admittedly some nights inside the restaurant were rather warm, but the open kitchen is part of the charm.',
#   'aspect': ['open kitchen', 'restaurant']},
#  {'id': 179,
#   'text': 'Great wine selection, Gigondas is worth the price, and the house champagne is a great value.',
#   'aspect': ['wine selection', 'Gigondas', 'house champagne']},
#  {'id': 180,
#   'text': 'It may be a bit packed on weekends, but the vibe is good and it is the best French food you will find in the area.',
#   'aspect': ['NULL', 'vibe', 'French food']},
#  {'id': 181,
#   'text': 'Have recommended the place to friends, always gets good response.',
#   'aspect': ['place']},
#  {'id': 182,
#   'text': 'Pizza - the only pizza in NYC that should not have additional toppings - the crust tastes like the best, freshly baked bread!',
#   'aspect': ['crust', 'pizza']},
#  {'id': 183, 'text': "Veal Parmigana - Better than Patsy's!", 'aspect': []},
#  {'id': 184, 'text': 'Much more reasonably priced too!', 'aspect': []},
#  {'id': 185, 'text': "I take all my NYC guests to VT's.", 'aspect': ["VT's"]},
#  {'id': 186,
#   'text': 'Not sure where the previous reviewer, lonk, dined, but Saul is in a great neighborhood and has great food!',
#   'aspect': ['neighborhood', 'food']},
#  {'id': 187,
#   'text': "I've been there three times and have always had wonderful experiences.",
#   'aspect': ['NULL']},
#  {'id': 188,
#   'text': "I'd highly recommend it for a special occasion -- it provides and intimate setting and nice service.",
#   'aspect': ['setting', 'service', 'NULL']},
#  {'id': 189,
#   'text': "I'm not sure where the other reviewers ate but it seems as if we visited two different restaurants because my friends and I all enjoy Mizu very much... and we're repeat customers.",
#   'aspect': ['Mizu']},
#  {'id': 190,
#   'text': 'Even after they overcharged me the last time I was there.',
#   'aspect': ['NULL']},
#  {'id': 191,
#   'text': 'Make sure you have the Spicy Scallop roll.. .',
#   'aspect': ['Spicy Scallop roll']},
#  {'id': 192, 'text': "it's delicious!", 'aspect': ['NULL']},
#  {'id': 193,
#   'text': 'Moules were excellent, lobster ravioli was VERY salty!',
#   'aspect': ['Moules', 'lobster ravioli']},
#  {'id': 194,
#   'text': "Took my mom for Mother's Day, and the maitre d' was pretty rude.",
#   'aspect': ["maitre d'"]},
#  {'id': 195,
#   'text': 'Told us to sit anywhere, and when we sat he said the table was reserved.',
#   'aspect': ['NULL']},
#  {'id': 196,
#   'text': 'Stepped on my foot on the SECOND time he reached over me to adjust lighting.',
#   'aspect': ['NULL']},
#  {'id': 197,
#   'text': 'Tiny dessert was $8.00...just plain overpriced for what it is.',
#   'aspect': ['dessert']},
#  {'id': 198,
#   'text': 'The drinks are always welll made and wine selection is fairly priced.',
#   'aspect': ['drinks', 'wine selection']},
#  {'id': 199,
#   'text': "Try their chef's specials-- they are to die for.",
#   'aspect': ["chef's specials"]},
#  {'id': 200,
#   'text': 'Service is not exactly five star, but thats not really a big deal.',
#   'aspect': ['Service']},
#  {'id': 201,
#   'text': 'Downstairs lounge is always a good attraction',
#   'aspect': ['Downstairs lounge']},
#  {'id': 202,
#   'text': "Raga's is a romantic, cozy restaurant.",
#   'aspect': ["Raga's"]},
#  {'id': 203,
#   'text': 'The exotic food is beautifully presented and is a delight in delicious combinations.',
#   'aspect': ['exotic food']},
#  {'id': 204, 'text': 'It is also extremely well priced.', 'aspect': ['NULL']},
#  {'id': 205,
#   'text': 'The staff is incredibly helpful and attentive.',
#   'aspect': ['staff']},
#  {'id': 206,
#   'text': 'The bar is very well stocked with interesting beers and well priced wines.',
#   'aspect': ['bar', 'beers', 'wines']},
#  {'id': 207,
#   'text': 'This is one of my favorite restaurants and it is not to be missed.',
#   'aspect': ['NULL']},
#  {'id': 208,
#   'text': 'Your friends will thank you for introducing them to this gem!',
#   'aspect': ['NULL']},
#  {'id': 209,
#   'text': 'When we stumbled on Leon, we thought that we had found quite the gem BUT, we were certainly wrong.',
#   'aspect': ['Leon']},
#  {'id': 210,
#   'text': 'The waitress moved our table practically into the bathroom and when we asked to cancel our dinner orders because we did not want to eat sitting on the toilet, we were told no...',
#   'aspect': ['waitress']},
#  {'id': 211,
#   'text': "Then, to top things off, she dropped used silverware on my boyfriend's jacket and did not stop to apologize or clean the mess that was left on clothes. ",
#   'aspect': ['NULL']},
#  {'id': 212, 'text': 'Such a disappointment...', 'aspect': ['NULL']},
#  {'id': 213,
#   'text': 'Rude service, medicore food...there are tons of restaurants in NY...stay away from this one',
#   'aspect': ['service', 'food', 'NULL']},
#  {'id': 214,
#   'text': 'I had a grat time at Jekyll and Hyde!',
#   'aspect': ['Jekyll and Hyde']},
#  {'id': 215,
#   'text': 'I loved everythig about it-especially the shows and actors.',
#   'aspect': ['NULL', 'shows', 'actors']},
#  {'id': 216,
#   'text': 'Our server was very helpful and friendly.',
#   'aspect': ['server']},
#  {'id': 217,
#   'text': 'I am bringing my whole family back next time.',
#   'aspect': ['NULL']},
#  {'id': 218, 'text': 'The food was good too.', 'aspect': ['food']},
#  {'id': 219,
#   'text': 'The tuna and wasabe potatoes are excellent.',
#   'aspect': ['tuna', 'wasabe potatoes']},
#  {'id': 220,
#   'text': 'The outdoor atmosphere of sitting on the sidewalk watching the world go by 50 feet away on 6th avenue on a cool evening was wonderful.',
#   'aspect': ['outdoor atmosphere']},
#  {'id': 221,
#   'text': 'Inside is a little cramped, but to be expected.',
#   'aspect': ['NULL']},
#  {'id': 222,
#   'text': 'Service was prompt and courteous.',
#   'aspect': ['Service']},
#  {'id': 223,
#   'text': "This was a repeat visit and we'll definitely be back again.",
#   'aspect': ['NULL']},
#  {'id': 224,
#   'text': 'Great service, great food.',
#   'aspect': ['service', 'food']},
#  {'id': 225, 'text': 'Prices are in line.', 'aspect': ['NULL']},
#  {'id': 226,
#   'text': 'Compared to other shabu restaurants around town, this places wins hands-down.',
#   'aspect': []},
#  {'id': 227, 'text': 'But too far east!', 'aspect': ['NULL']},
#  {'id': 228,
#   'text': "I live a block away and go to Patsy's frequently.",
#   'aspect': []},
#  {'id': 229,
#   'text': "The pizza is delicious - they use fresh mozzarella instead of the cheap, frozen, shredded cheese common to most pizzaria's.",
#   'aspect': ['pizza', 'fresh mozzarella']},
#  {'id': 230,
#   'text': 'Two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu.',
#   'aspect': ['appetizer selection']},
#  {'id': 231,
#   'text': 'Also, because it is so thin, it gets cold very quickly and its not that filling.',
#   'aspect': ['NULL']},
#  {'id': 232, 'text': 'So eat fast and order a lot.', 'aspect': []},
#  {'id': 233,
#   'text': 'Wait staff is blantently unappreciative of your business but its the best pie on the UWS!',
#   'aspect': ['Wait staff', 'pie']},
#  {'id': 234,
#   'text': 'By far the best salad I have had in a fast food restaurant.',
#   'aspect': ['salad']},
#  {'id': 235, 'text': 'fine dining restaurant quality.', 'aspect': ['dining']},
#  {'id': 236,
#   'text': 'Over 100 different choices to create your own.',
#   'aspect': ['NULL']},
#  {'id': 237, 'text': 'A must try!', 'aspect': ['NULL']},
#  {'id': 238,
#   'text': 'On a recent Sunday afternoon, a friend and I accidently found this great restaurant on our way to see the pulitzer prize winning play DOUBT.',
#   'aspect': ['restaurant']},
#  {'id': 239,
#   'text': 'This was the perfect quiet, relaxing, and delicious accompaniment to our afternoon of theater.',
#   'aspect': ['NULL']},
#  {'id': 240,
#   'text': 'The chicken pot pie is excpetiona, the cheeseburger huge and delictable, and the service professional wan warm.',
#   'aspect': ['chicken pot pie', 'cheeseburger', 'service']},
#  {'id': 241,
#   'text': 'With so many poor experiences to be had in the theater district, is truly an excellent find!',
#   'aspect': ['NULL']},
#  {'id': 242,
#   'text': 'We will return many times for this oasis in mid-town.',
#   'aspect': ['NULL']},
#  {'id': 243, 'text': 'I grew up on these bagels.', 'aspect': []},
#  {'id': 244, 'text': 'The staff is no nonsense.', 'aspect': ['staff']},
#  {'id': 245, 'text': 'The food options rule.', 'aspect': ['food']},
#  {'id': 246,
#   'text': 'When I lived upstate for a while I would buy freeze the bagels and they would still be better than any else.',
#   'aspect': ['bagels']},
#  {'id': 247,
#   'text': 'Worth visiting the 1st Ave spot because it is the original store.',
#   'aspect': ['1st Ave spot']},
#  {'id': 248,
#   'text': 'I stumbled upon this second floor walk-up two Fridays ago when I was with two friends in town from L.A. ',
#   'aspect': []},
#  {'id': 249,
#   'text': 'Being serious sushi lovers, we sat at the sushi bar to be closer to the action.',
#   'aspect': []},
#  {'id': 250,
#   'text': 'I asked the chef what he recommends and he asked me if I like Uni. (',
#   'aspect': []},
#  {'id': 251,
#   'text': "For those of you who don't know, Uni is Sea Urchin in Japanese, which happens to be my favorite.) ",
#   'aspect': []},
#  {'id': 252,
#   'text': 'He served me an Uni Hand roll, which I never had before, and let me tell you...IT WAS HEAVEN!',
#   'aspect': ['Uni Hand roll']},
#  {'id': 253,
#   'text': 'Aside from the Sea Urchin, the chef recommended an assortment of fish including Fatty Yellow Tail, Boton Shrimp, Blue Fin Torro (Fatty Tuna), Sea Eel, etc.',
#   'aspect': []},
#  {'id': 254,
#   'text': 'The sake menu should not be overlooked!',
#   'aspect': ['sake menu']},
#  {'id': 255,
#   'text': 'All in all, this midtown gem instantly became one of my favorite sushi restaurants in the city.',
#   'aspect': ['NULL']},
#  {'id': 256,
#   'text': 'Try the lobster teriyaki and the rose special roll.',
#   'aspect': ['lobster teriyaki', 'rose special roll']},
#  {'id': 257,
#   'text': 'We visited Orsay during NY Restaurant Week and tried their $35 menu.',
#   'aspect': []},
#  {'id': 258,
#   'text': 'Service was very good - prompt, attentive and non-intrusive.',
#   'aspect': ['Service']},
#  {'id': 259,
#   'text': 'Food was very good as well, considering that we tried the budget selection (though I wish the pork belly that I ordered was roasted a bit longer, so that fat was more of a melt-in-your-mouth experience).',
#   'aspect': ['Food', 'pork belly']},
#  {'id': 260,
#   'text': 'Wine list selection is good and wine-by-the-glass was generously filled to the top.',
#   'aspect': ['Wine list selection', 'wine-by-the-glass']},
#  {'id': 261,
#   'text': 'Traditional French decour was pleasant though the hall was rather noisy - the restaurant was full and we had to raise our voices to be able to maintain a conversation.',
#   'aspect': ['Traditional French decour', 'hall']},
#  {'id': 262,
#   'text': "I've been to at Cafe Spice probably 5-8 times, it is probably still the best Indian restaurant around Union Square.",
#   'aspect': ['Cafe Spice']},
#  {'id': 263,
#   'text': 'To sum it up: Service varies from good to mediorce, depending on which waiter you get; generally it is just average Ok. ',
#   'aspect': ['Service']},
#  {'id': 264,
#   'text': 'Seating is always prompt, though the restaurant does fill up in the evening.',
#   'aspect': ['Seating']},
#  {'id': 265,
#   'text': 'Food is usually very good, though ocasionally I wondered about freshmess of raw vegatables in side orders.',
#   'aspect': ['Food', 'raw vegatables in side orders']},
#  {'id': 266,
#   'text': 'As many other reviewers noticed, your order is often slow to arrive - this is particularly true in the evening but is not a problem during lunch time.',
#   'aspect': ['NULL']},
#  {'id': 267,
#   'text': 'The decor is vibrant and eye-pleasing with several semi-private boths on the right side of the dining hall, which are great for a date.',
#   'aspect': ['decor', 'semi-private boths']},
#  {'id': 268,
#   'text': 'I have NEVER been disappointed in the Red Eye.',
#   'aspect': ['Red Eye']},
#  {'id': 269,
#   'text': 'The first time I went, and was completely taken by the live jazz band and atmosphere, I ordered the Lobster Cobb Salad.',
#   'aspect': ['live jazz band', 'atmosphere']},
#  {'id': 270,
#   'text': "I've never ordered anything else from their menu...there's no need to.",
#   'aspect': []},
#  {'id': 271, 'text': "It's simply the best meal in NYC.", 'aspect': ['meal']},
#  {'id': 272,
#   'text': 'You cannot go wrong at the Red Eye Grill.',
#   'aspect': ['Red Eye Grill']},
#  {'id': 273,
#   'text': 'If we were to move from the upper east side, we would genuinely miss this restaurant.',
#   'aspect': ['restaurant']},
#  {'id': 274,
#   'text': "We've lived in the area for more than 8 years.",
#   'aspect': []},
#  {'id': 275,
#   'text': 'The restaurant is cute but not upscale.',
#   'aspect': ['restaurant']},
#  {'id': 276,
#   'text': 'The food is a diamond in rough -- the food is delicious and homemade with the perfect balance of herbs and tomatoes.',
#   'aspect': ['food', 'balance of herbs and tomatoes']},
#  {'id': 277, 'text': 'I would highly recommend it.', 'aspect': ['NULL']},
#  {'id': 278,
#   'text': "It's one of our favorite places to eat in NY.",
#   'aspect': ['NULL']},
#  {'id': 279,
#   'text': 'We had a great time at the Jekyll and hyde Pub last night.',
#   'aspect': ['Jekyll and hyde Pub']},
#  {'id': 280,
#   'text': 'We were walking around the village and went into this place just for some drinks.',
#   'aspect': []},
#  {'id': 281,
#   'text': 'After really enjoying ourselves at the bar we sat down at a table and had dinner.',
#   'aspect': ['bar']},
#  {'id': 282,
#   'text': 'The server was really cool and served us our food and drinks with a smile.',
#   'aspect': ['server']},
#  {'id': 283,
#   'text': "The place's decor and hidden bathrooms made for a good laugh.",
#   'aspect': ['decor', 'hidden bathrooms']},
#  {'id': 284,
#   'text': 'I highly recommend visiting this restaurant and having dinner and drinks!',
#   'aspect': ['restaurant']},
#  {'id': 285,
#   'text': 'If you are the type of person who likes being scared and entertained, this is a great place to go and eat.',
#   'aspect': ['place']},
#  {'id': 286,
#   'text': 'My husband and I thougt it would be great to go to the Jekyll and Hyde Pub for our anniversary, and to our surprise it was fantastic.',
#   'aspect': ['Jekyll and Hyde Pub']},
#  {'id': 287,
#   'text': 'The have over 100 different beers to offer thier guest so that made my husband very happy and the food was delicious, if I must recommend a dish it must be the pumkin tortelini.',
#   'aspect': ['beers', 'food', 'pumkin tortelini']},
#  {'id': 288,
#   'text': 'The entertainment was great they have shows that go on through out the dinner.',
#   'aspect': ['NULL']},
#  {'id': 289,
#   'text': 'Please take my advice, go and try this place.',
#   'aspect': ['place']},
#  {'id': 290, 'text': 'Its located in greenewich village.', 'aspect': []},
#  {'id': 291,
#   'text': 'You will not be disapointed at all.',
#   'aspect': ['NULL']},
#  {'id': 292,
#   'text': 'Our first time in New York and we had to try a New York Bagel.',
#   'aspect': []},
#  {'id': 293,
#   'text': 'We were not dissappointed in the least bit by this little gem.',
#   'aspect': ['NULL']},
#  {'id': 294, 'text': 'The bagel was huge.', 'aspect': ['bagel']},
#  {'id': 295,
#   'text': 'They were served warm and had a soft fluffy interior.',
#   'aspect': ['NULL']},
#  {'id': 296,
#   'text': 'The workers there also absolutely load the bagel with cream cheese (gets a little messy).',
#   'aspect': ['bagel']},
#  {'id': 297,
#   'text': 'I loved it and would HIGHLY RECOMMEND.',
#   'aspect': ['NULL']},
#  {'id': 298,
#   'text': "This was my frist time at Cafe St. Bart's and I must say how delicous the food and the service was.",
#   'aspect': ['food', 'service']},
#  {'id': 299,
#   'text': "When I called this morning, I didn't think I would be able to get in at 12, but I was able to get in, along with four other guests.",
#   'aspect': []},
#  {'id': 300,
#   'text': 'I have to highly recommend the lobster roll - not to much mayo; you can tell it was a fresh lobster.',
#   'aspect': ['lobster roll', 'lobster']},
#  {'id': 301,
#   'text': 'Other guests enjoyed pizza, santa fe chopped salad and fish and chips.',
#   'aspect': ['pizza', 'santa fe chopped salad', 'fish and chips']},
#  {'id': 302,
#   'text': "I highly recommend Cafe St. Bart's for their food, the ambience and wonderful service.",
#   'aspect': ['food', 'ambience', 'service']},
#  {'id': 303,
#   'text': 'All the staff is absolutely professional!! ',
#   'aspect': ['staff']},
#  {'id': 304,
#   'text': "I sometimes see the waiters don't have enough knowledge of their dishes.",
#   'aspect': []},
#  {'id': 305, 'text': 'But they do.', 'aspect': ['NULL']},
#  {'id': 306,
#   'text': '(that is A MUST, but not every restaurant can do...) ',
#   'aspect': ['NULL']},
#  {'id': 307,
#   'text': 'If you want to dine with large party, I recommend to make reservation BASEMENT.',
#   'aspect': []},
#  {'id': 308,
#   'text': "There's nice and quiet, small but enough for 6 (or more).",
#   'aspect': ['NULL']},
#  {'id': 309,
#   'text': 'This restaurant was way overhyped.',
#   'aspect': ['restaurant']},
#  {'id': 310,
#   'text': 'My chow fun and chow see was really bland and oily.',
#   'aspect': ['chow fun and chow see']},
#  {'id': 311,
#   'text': "Okay-i don't mind the oily part (cause most are cooked that way) but it was way too bland.",
#   'aspect': ['NULL']},
#  {'id': 312,
#   'text': 'The scallion pancakes and fried dumplings were nothing out of the ordinary.',
#   'aspect': ['scallion pancakes', 'fried dumplings']},
#  {'id': 313,
#   'text': 'The service was the only thing good about this restaurant.',
#   'aspect': ['service', 'restaurant']},
#  {'id': 314,
#   'text': "It's boring on the inside, and our sushi was pretty below average... the tuna was soggy and the other rolls had no flavor.",
#   'aspect': ['NULL', 'sushi', 'tuna', 'rolls']},
#  {'id': 315, 'text': "I definitely wouldn't go back.", 'aspect': ['NULL']},
#  {'id': 316,
#   'text': 'There are many Thai places in the city but so far Toons is #1.',
#   'aspect': []},
#  {'id': 317,
#   'text': 'Their pad penang is delicious and everything else is fantastic.',
#   'aspect': ['pad penang', 'NULL']},
#  {'id': 318,
#   'text': 'The price is reasonable although the service is poor.',
#   'aspect': ['NULL', 'service']},
#  {'id': 319,
#   'text': 'fresh restaurant was amazing........ food was delicious and of course fresh.',
#   'aspect': ['fresh restaurant', 'food']},
#  {'id': 320,
#   'text': 'great for a romantic evening, or a fun evening with friends...',
#   'aspect': ['NULL']},
#  {'id': 321, 'text': 'I will be going back very soon.', 'aspect': ['NULL']},
#  {'id': 322, 'text': 'keep up the good work.', 'aspect': ['NULL']},
#  {'id': 323, 'text': 'Hats off to the chef.', 'aspect': ['chef']},
#  {'id': 324,
#   'text': 'I am not the most experienced person when it comes to Thai food, but my friend who took me there is.',
#   'aspect': []},
#  {'id': 325,
#   'text': 'He has visited Thailand and is quite expert on the cuisine.',
#   'aspect': []},
#  {'id': 326, 'text': 'It was wonderful.', 'aspect': ['NULL']},
#  {'id': 327,
#   'text': 'the salads are delicious, both refreshing and very spicy.',
#   'aspect': ['salads']},
#  {'id': 328,
#   'text': "We had Pam's special fried fish and it was amazing.",
#   'aspect': ["Pam's special fried fish"]},
#  {'id': 329,
#   'text': 'too large for just two people but nothing was left.',
#   'aspect': ['NULL']},
#  {'id': 330, 'text': 'Unbelievable.', 'aspect': []},
#  {'id': 331,
#   'text': 'Had a late night dinner on a Saturday night.',
#   'aspect': []},
#  {'id': 332, 'text': 'Great vibe, lots of people.', 'aspect': ['vibe']},
#  {'id': 333,
#   'text': 'My husband and I both ordered the Steak, medium.',
#   'aspect': []},
#  {'id': 334,
#   'text': 'My husbands was perfect, my was well done and dry.',
#   'aspect': ['NULL']},
#  {'id': 335,
#   'text': "I didn't complain, I liked the atmosphere so much.",
#   'aspect': ['atmosphere']},
#  {'id': 336,
#   'text': 'Will give it another chance before I write it off.',
#   'aspect': []},
#  {'id': 337,
#   'text': 'Visited there while on vacation and reading the reviews.',
#   'aspect': []},
#  {'id': 338,
#   'text': 'On a hot day it was fabulous to stop in and enjoy lunch.',
#   'aspect': ['NULL']},
#  {'id': 339,
#   'text': 'Ambience is so cute and quaint, good for business although we were there on vacation.',
#   'aspect': ['Ambience', 'NULL']},
#  {'id': 340, 'text': 'Salads were fantastic.', 'aspect': ['Salads']},
#  {'id': 341,
#   'text': 'Although we were looking for regular lettuce and some walnuts the salads we got were great.',
#   'aspect': ['salads']},
#  {'id': 342,
#   'text': 'Ingredients are organic which is a real plus for me.',
#   'aspect': ['Ingredients']},
#  {'id': 343, 'text': 'We will be back.', 'aspect': ['NULL']},
#  {'id': 344,
#   'text': 'This is some really good, inexpensive sushi.',
#   'aspect': ['sushi']},
#  {'id': 345,
#   'text': "It costs $2 extra to turn a regular roll into an inside-out roll, but the roll more than triples in size, and that's not just from the rice.",
#   'aspect': []},
#  {'id': 346,
#   'text': "The spicy Tuna roll is huge and probably the best that I've had at this price range.",
#   'aspect': ['spicy Tuna roll']},
#  {'id': 347,
#   'text': 'The Yellowtail was particularly good as well.',
#   'aspect': ['Yellowtail']},
#  {'id': 348,
#   'text': 'I have reservations about the all you can eat deal, however -- the choices are fairly limited and you can probably order more food than you can eat for less than $18 by just going off the menu.',
#   'aspect': ['all you can eat deal']},
#  {'id': 349,
#   'text': "In any event, this is a place I'll be sure to stop by again when I'm in this part of town.",
#   'aspect': ['place']},
#  {'id': 350,
#   'text': 'Big Wong gets big Ups for a fine establishment.',
#   'aspect': ['Big Wong']},
#  {'id': 351,
#   'text': 'They have it all -- great price, food, and service.',
#   'aspect': ['NULL', 'food', 'service']},
#  {'id': 352,
#   'text': 'The atmosphere is noisy and the waiters are literally walking around doing things as fast as they can.',
#   'aspect': ['atmosphere', 'waiters']},
#  {'id': 353,
#   'text': 'The food is prepared quickly and efficiently.',
#   'aspect': ['NULL']},
#  {'id': 354,
#   'text': 'And it all comes at a very reasonable price (congee, noodles, and rice dishes are no more than $3-6 each).',
#   'aspect': ['NULL', 'congee', 'noodles', 'rice dishes']},
#  {'id': 355,
#   'text': 'The takeout is great too since they give high quality tupperware as well.',
#   'aspect': ['takeout']},
#  {'id': 356,
#   'text': 'This place is always very crowded and popular.',
#   'aspect': ['place']},
#  {'id': 357, 'text': "Went here on a friend's reccomendation.", 'aspect': []},
#  {'id': 358,
#   'text': 'Enjoyed a very nice Caesar Salad while my wife had arugula and goat cheese....both very tasty.',
#   'aspect': ['Caesar Salad', 'arugula and goat cheese']},
#  {'id': 359,
#   'text': 'We both opted for a pasta dish and they were served timely and fresh.',
#   'aspect': ['NULL', 'pasta dish']},
#  {'id': 360,
#   'text': 'We concluded with tiramisu chocolate cake, both were delicious.',
#   'aspect': ['tiramisu', 'chocolate cake']},
#  {'id': 361, 'text': "We'd go back again", 'aspect': ['NULL']},
#  {'id': 362,
#   'text': 'I recently went to this restaurant with some co-workers for lunch and had an amazing time.',
#   'aspect': ['restaurant']},
#  {'id': 363,
#   'text': 'The staff was accomodating, the food was absolutely delicious and the place is lovely.',
#   'aspect': ['staff', 'food', 'place']},
#  {'id': 364,
#   'text': 'We even had a visit from the Manager who wanted to make sure we were enjoying ourselves.',
#   'aspect': ['Manager']},
#  {'id': 365,
#   'text': 'Yes, the prices are high, but I felt it was worth it.',
#   'aspect': ['NULL']},
#  {'id': 366, 'text': 'We all felt it was worth it.', 'aspect': ['NULL']},
#  {'id': 367,
#   'text': 'sometimes i get good food and ok service.',
#   'aspect': ['food', 'service']},
#  {'id': 368,
#   'text': 'sometimes i get bad food and bad service, sometimes i get good good and bad service.',
#   'aspect': ['food', 'service', 'good']},
#  {'id': 369, 'text': 'it is not consistent.', 'aspect': ['NULL']},
#  {'id': 370, 'text': 'really depends on your luck!', 'aspect': []},
#  {'id': 371,
#   'text': 'The place is a BISTRO which means: simple dishes and wine served efficiently in a bustling atmosphere.',
#   'aspect': ['dishes', 'wine', 'NULL', 'atmosphere']},
#  {'id': 372,
#   'text': 'And where does Patis go wrong; no where. ',
#   'aspect': ['Patis']},
#  {'id': 373,
#   'text': 'You are not eating haut cuisine with subtle hints of whatever but: Cassuolet, Steake Fritte, Tripe Stew, etc; simple stuff.',
#   'aspect': ['NULL']},
#  {'id': 374,
#   'text': 'And evaluated on those terms Pastis is simply wonderful.',
#   'aspect': ['Pastis']},
#  {'id': 375,
#   'text': 'Right off the L in Brooklyn this is a nice cozy place with good pizza.',
#   'aspect': ['pizza', 'place']},
#  {'id': 376,
#   'text': 'Mine was a little burnt but still delicious with goat cheese and panchetta (raddichio was kind of bitter though).',
#   'aspect': ['raddichio', 'NULL']},
#  {'id': 377,
#   'text': 'My friend got the mushroom pizza which tasted better.',
#   'aspect': ['mushroom pizza']},
#  {'id': 378,
#   'text': 'The sangria was pretty tasty and good on a hot muggy day.',
#   'aspect': ['sangria']},
#  {'id': 379,
#   'text': 'Kind of a small place but I guess if they are not too busy might be able to fit a group or kids.',
#   'aspect': ['place']},
#  {'id': 380,
#   'text': 'Overall I would recommend it and go back again.',
#   'aspect': ['NULL']},
#  {'id': 381,
#   'text': "Coming from Boston this place is like Emma's Pizza in Kendall Square in Cambridge (although they have more funky toppings!)",
#   'aspect': []},
#  {'id': 382,
#   'text': 'I started out with a Bombay beer which was big enough for two.',
#   'aspect': ['Bombay beer']},
#  {'id': 383,
#   'text': 'For dinner I had the chicken tikka-masala and some garlic naan.',
#   'aspect': []},
#  {'id': 384, 'text': 'MMmmm... it was delicious.', 'aspect': ['NULL']},
#  {'id': 385,
#   'text': 'Service was slow, but the people were friendly.',
#   'aspect': ['Service', 'people']},
#  {'id': 386,
#   'text': "It's a nice place to relax and have conversation.",
#   'aspect': ['place']},
#  {'id': 387, 'text': "I can't wait to go back.", 'aspect': ['NULL']},
#  {'id': 388,
#   'text': 'We have lived in Chelsea for two years and have never noticed this restaurant.',
#   'aspect': []},
#  {'id': 389,
#   'text': 'The food is authentic Italian - delicious!',
#   'aspect': ['food']},
#  {'id': 390,
# ...
#  {'id': 866,
#   'text': "Even if the food wasn't this good, the garden is a great place to sit outside and relax.",
#   'aspect': ['garden', 'food']},
#  {'id': 867, 'text': 'Great neighborhood joint.', 'aspect': ['joint']},
#  {'id': 868,
#   'text': 'This is a nice pizza place with good selection of thin crust pizza including the Basil slice.',
#   'aspect': ['selection of thin crust pizza', 'pizza place', 'Basil slice']},
#  {'id': 869,
#   'text': 'Their calzones are horrific, bad, vomit-inducing, YUCK.',
#   'aspect': ['calzones']},
#  {'id': 870,
#   'text': 'They smell like they stuff them with old canned vegetables like the spinach mushroom calzone.',
#   'aspect': ['NULL']},
#  {'id': 871,
#   'text': 'The counter service is bad.',
#   'aspect': ['counter service']},
#  {'id': 872,
#   'text': 'They charge different prices all the time.',
#   'aspect': ['NULL']},
#  {'id': 873,
#   'text': "They're rude at times, and not very friendly.",
#   'aspect': ['NULL']},
#  {'id': 874, 'text': 'NO PIZZA 33 for me!', 'aspect': ['PIZZA 33']},
#  {'id': 875,
#   'text': 'Anybody who likes this place must be from a different planet, where greasy, dry and tasteless are complimentary.',
#   'aspect': ['NULL']},
#  {'id': 876,
#   'text': "The dosas are skimpy, unattractive and drip with grease, and personally I'd drink popcorn topping before I'd eat another one of these.",
#   'aspect': ['dosas']},
#  {'id': 877,
#   'text': 'The sandwiches are dry, tasteless and way overpriced.',
#   'aspect': ['sandwiches']},
#  {'id': 878,
#   'text': 'Calling the place Hampton Chutney Co. does warn you that these folks offer more style than substance, but in this unattractive room with unhelpful clerks there was a dearth of the former too.',
#   'aspect': ['place', 'room', 'clerks']},
#  {'id': 879, 'text': 'Seriously, this place kicks ass.', 'aspect': ['place']},
#  {'id': 880,
#   'text': 'The atmosphere is unheralded, the service impecible, and the food magnificant.',
#   'aspect': ['atmosphere', 'service', 'food']},
#  {'id': 881,
#   'text': 'Best Italian food I ever had (and being Italian, that means alot).',
#   'aspect': ['Italian food']},
#  {'id': 882,
#   'text': 'It is nearly impossible to get a table, so if you ever have the chance to go here for dinner, DO NOT pass it up.',
#   'aspect': ['NULL']},
#  {'id': 883,
#   'text': 'This is such a lovely, peaceful place to eat outside.',
#   'aspect': ['place']},
#  {'id': 884,
#   'text': 'The restaurant looks out over beautiful green lawns to the Hudson River and the Statue of Liberty.',
#   'aspect': ['restaurant']},
#  {'id': 885,
#   'text': "It is set far from the small street it's on, and there is no traffic noise.",
#   'aspect': ['NULL']},
#  {'id': 886,
#   'text': 'The food is good, especially their more basic dishes, and the drinks are delicious.',
#   'aspect': ['food', 'basic dishes', 'drinks']},
#  {'id': 887,
#   'text': 'This is a great place to take out-of-towners, and perfect for watching the sunset.',
#   'aspect': ['place']},
#  {'id': 888, 'text': 'Great sushi experience.', 'aspect': ['sushi']},
#  {'id': 889, 'text': 'Nice value.', 'aspect': ['NULL']},
#  {'id': 890, 'text': 'Unique apppetizers.', 'aspect': ['apppetizers']},
#  {'id': 891,
#   'text': 'Try sushimi cucumber roll.',
#   'aspect': ['sushimi cucumber roll']},
#  {'id': 892,
#   'text': 'Good spreads, great beverage selections and bagels really tasty.',
#   'aspect': ['spreads', 'beverage selections', 'bagels']},
#  {'id': 893,
#   'text': 'THE BIG COMPLAINT: NO TOASTING AVAILABLE.',
#   'aspect': ['NULL']},
#  {'id': 894,
#   'text': 'I complete the total bagel experience by having it lightly toasted.',
#   'aspect': []},
#  {'id': 895, 'text': "Murray won't do it.", 'aspect': ['NULL']},
#  {'id': 896,
#   'text': "Won't or Can't is not in the service directory.",
#   'aspect': ['NULL']},
#  {'id': 897,
#   'text': "But who says Murray's is anything about service.",
#   'aspect': ['service']},
#  {'id': 898, 'text': 'So close, but not good enough.', 'aspect': ['NULL']},
#  {'id': 899,
#   'text': "Don't be fooled by crowds of people.",
#   'aspect': ['NULL']},
#  {'id': 900, 'text': 'The service is awful.', 'aspect': ['service']},
#  {'id': 901,
#   'text': 'This place is not worth the prices.',
#   'aspect': ['place']},
#  {'id': 902,
#   'text': "Also, don't plan on asking for your favorite roll, if it's not on the menu, you can't have it.",
#   'aspect': ['NULL']},
#  {'id': 903, 'text': 'Love Pizza 33..', 'aspect': ['Pizza 33']},
#  {'id': 904,
#   'text': 'I will be out with friends and all of a sudden I am hungry and I only crave one thing... their Pizza.',
#   'aspect': ['Pizza']},
#  {'id': 905,
#   'text': 'I live in the neightborhood and am a regular.',
#   'aspect': []},
#  {'id': 906, 'text': 'It hits the spot every time', 'aspect': ['NULL']},
#  {'id': 907,
#   'text': 'This tiny Williamsburg spot is always pleasantly surprising.',
#   'aspect': ['Williamsburg spot']},
#  {'id': 908,
#   'text': 'The pizza is delicious and the proprietor is one of the nicest in NYC.',
#   'aspect': ['pizza', 'proprietor']},
#  {'id': 909,
#   'text': 'Even the pasta is delicious here (a rarity in New York pizza restaurants).',
#   'aspect': []},
#  {'id': 910,
#   'text': "I've been many time and have never been disappointed.",
#   'aspect': ['NULL']},
#  {'id': 911,
#   'text': 'Compared to Ess-a, Tal offers a less doughy bagel!',
#   'aspect': []},
#  {'id': 912,
#   'text': 'They even scoop it out nice (for those on a diet) not too much not to little.',
#   'aspect': ['NULL']},
#  {'id': 913,
#   'text': 'The cream cheeses are out of this world and I love that coffee!!',
#   'aspect': ['cream cheeses', 'coffee']},
#  {'id': 914,
#   'text': 'A little crowded but they move that line really fast!',
#   'aspect': ['NULL']},
#  {'id': 915,
#   'text': 'A little pricey but it really hits the spot on a Sunday morning!',
#   'aspect': ['NULL']},
#  {'id': 916,
#   'text': 'Bagels are ok, but be sure not to make any special requests!',
#   'aspect': ['Bagels', 'NULL']},
#  {'id': 917,
#   'text': 'I asked for an open faced cheese sandwich and the manager basically told me to take my business elsewhere!',
#   'aspect': ['manager']},
#  {'id': 918,
#   'text': 'Be sure not to get anything other than bagels!..',
#   'aspect': ['NULL', 'bagels']},
#  {'id': 919,
#   'text': 'the turkey burgers are scary!',
#   'aspect': ['turkey burgers']},
#  {'id': 920,
#   'text': "The worst excuse for Japanese food I've ever encountered.",
#   'aspect': ['Japanese food']},
#  {'id': 921,
#   'text': 'The soup for the udon was soy sauce and water.',
#   'aspect': ['soup for the udon']},
#  {'id': 922, 'text': 'The sushi was awful!', 'aspect': ['sushi']},
#  {'id': 923,
#   'text': 'The rice was poor quality and was cooked so badly it was hard.',
#   'aspect': ['rice']},
#  {'id': 924,
#   'text': 'Furthermore, the rice had no seasoning, so the sushi was bland and disgusting.',
#   'aspect': ['rice', 'sushi']},
#  {'id': 925,
#   'text': 'The fish was adequate, but inexpertly sliced.',
#   'aspect': ['fish']},
#  {'id': 926,
#   'text': 'It is obvious that no one in the restaurant has any idea about or experience with Japanese cuisine.',
#   'aspect': ['Japanese cuisine']},
#  {'id': 927, 'text': 'Good, fast service.', 'aspect': ['service']},
#  {'id': 928, 'text': 'I would highly recommend.', 'aspect': ['NULL']},
#  {'id': 929, 'text': 'Food is great and inexpensive.', 'aspect': ['Food']},
#  {'id': 930, 'text': 'The location is perfect.', 'aspect': ['location']},
#  {'id': 931, 'text': 'Give it a try and enjoy.', 'aspect': ['NULL']},
#  {'id': 932,
#   'text': 'I thought going to Jimmys would give me a real Domincan exprience.',
#   'aspect': []},
#  {'id': 933, 'text': 'Jimmy is Dominican!', 'aspect': []},
#  {'id': 934,
#   'text': 'Well, this place is so Ghetto its not even funny.',
#   'aspect': ['place']},
#  {'id': 935,
#   'text': "If you like your music blasted and the system isnt that great and if you want to pay at least 100 dollar bottle minimun then you'll love it here.",
#   'aspect': ['bottle minimun', 'music']},
#  {'id': 936, 'text': 'Would NEVER go back there.', 'aspect': ['NULL']},
#  {'id': 937, 'text': 'Too bad Latin Quarters closed.', 'aspect': []},
#  {'id': 938, 'text': 'That place was awesome,,,  sally !', 'aspect': []},
#  {'id': 939,
#   'text': 'Awsome Pizza especially the Margheritta slice.',
#   'aspect': ['Pizza', 'Margheritta slice']},
#  {'id': 940, 'text': 'Always busy but fast moving.', 'aspect': ['NULL']},
#  {'id': 941,
#   'text': 'Great atmoshere and worth every bit.',
#   'aspect': ['atmoshere', 'NULL']},
#  {'id': 942,
#   'text': "Open late (well as late as I ever got there and I'm a night person)",
#   'aspect': ['NULL']},
#  {'id': 943,
#   'text': 'Winnie and her staff are the best crew you can find serving you.',
#   'aspect': ['staff', 'Winnie']},
#  {'id': 944,
#   'text': 'The food is reliable and the price is moderate.',
#   'aspect': ['food', 'NULL']},
#  {'id': 945, 'text': 'What more can you ask for?', 'aspect': ['NULL']},
#  {'id': 946,
#   'text': 'For authentic Thai food, look no further than Toons.',
#   'aspect': ['Thai food']},
#  {'id': 947,
#   'text': "Ive been to many Thai restaurants in Manhattan before, and Toons is by far the best Thai food Ive had (except for my mom's of course).",
#   'aspect': []},
#  {'id': 948,
#   'text': "Try the Pad Thai, or sample anything on the appetizer menu...they're all delicious.",
#   'aspect': ['Pad Thai', 'appetizer menu']},
#  {'id': 949,
#   'text': 'Everything about this restaurant was special.',
#   'aspect': ['restaurant']},
#  {'id': 950,
#   'text': 'The service was attentive, yet discreet.',
#   'aspect': ['service']},
#  {'id': 951, 'text': 'The flavors robust and subtle.', 'aspect': ['NULL']},
#  {'id': 952,
#   'text': 'The brioche and lollies as party favors is a cute and sweet touch to a most memorable meal.',
#   'aspect': ['brioche and lollies']},
#  {'id': 953, 'text': "I'm saving up for my next visit.", 'aspect': ['NULL']},
#  {'id': 954,
#   'text': 'I went there in late afternoon for some bite size food and refleshment with my date.',
#   'aspect': []},
#  {'id': 955,
#   'text': 'The place was quiet and delightful.',
#   'aspect': ['place']},
#  {'id': 956,
#   'text': 'Service was good and food is wonderful.',
#   'aspect': ['Service', 'food']},
#  {'id': 957,
#   'text': 'I did not try the caviar but I tried their salmon and crab salad (they are all good)  ',
#   'aspect': ['salmon', 'crab salad']},
#  {'id': 958,
#   'text': 'It is definitely a good spot for snacks and chat.',
#   'aspect': ['spot']},
#  {'id': 959,
#   'text': 'As a retired hipster, I can say with some degree of certainty that for the last year Lucky Strike has been the best laid-back late night in the city.',
#   'aspect': ['Lucky Strike']},
#  {'id': 960,
#   'text': "The wait staff is pleasant, fun, and for the most part gorgeous (in the wonderful aesthetic beautification way, not in that she's-way-cuter-than-me-that-b@#$* way).",
#   'aspect': ['wait staff']},
#  {'id': 961,
#   'text': 'The food is yummy, especially their cooked-to-perfection mussels in spicy tomato sauce and their shoestring crispy fries.',
#   'aspect': ['food', 'mussels in spicy tomato sauce', 'fries']},
#  {'id': 962,
#   'text': 'But the best part about LS is the late night atmosphere, delightfully free of the BTs.',
#   'aspect': ['late night atmosphere']},
#  {'id': 963,
#   'text': "You can get a completely delish martini in a glass (that's about 2 1/2 drinks) for $8.50 (I recommend the Vanilla Shanty, mmmm!) in a great homey setting with great music.",
#   'aspect': ['martini', 'Vanilla Shanty', 'setting', 'music']},
#  {'id': 964,
#   'text': 'The in-house lady DJ on Saturday nights has outrageously good taste in music, and moreover, takes requests.',
#   'aspect': ['in-house lady DJ']},
#  {'id': 965,
#   'text': "You can't go wrong with this place.",
#   'aspect': ['place']},
#  {'id': 966,
#   'text': 'Suan is a great place that I often take my friends (classmates) too.',
#   'aspect': ['Suan']},
#  {'id': 967,
#   'text': 'Its location is good and the fact that Hutner College is near and their prices are very reasonable, makes students go back to Suan again and again.',
#   'aspect': ['location', 'Suan']},
#  {'id': 968, 'text': 'I LOVE their Thai', 'aspect': ['Thai']},
#  {'id': 969,
#   'text': 'noodles with shrimp and chicken and coconut juice is the MUST!',
#   'aspect': ['noodles with shrimp and chicken and coconut juice']},
#  {'id': 970,
#   'text': 'I was in love with Pongsri on 48th, but compared to Suan it is slow in service and overpriced.',
#   'aspect': []},
#  {'id': 971, 'text': 'I will go back to Suan soon!', 'aspect': ['Suan']},
#  {'id': 972,
#   'text': 'In summer-eat outside on a terrace (another great feature of Suan)!!!',
#   'aspect': ['terrace']},
#  {'id': 973,
#   'text': 'I cannot imagine a friendlier staff working in a restaurant.',
#   'aspect': ['staff']},
#  {'id': 974,
#   'text': 'I cannot imagine better Indian food in all of the city.',
#   'aspect': ['Indian food']},
#  {'id': 975,
#   'text': 'I cannot imagine you not rushing out to eat there.',
#   'aspect': ['NULL']},
#  {'id': 976,
#   'text': 'This restaurant used to be our regular Thursday night dinner location.',
#   'aspect': []},
#  {'id': 977,
#   'text': 'During the course of the past 3 months, the chef and staff changed and it was not for the better.',
#   'aspect': ['chef', 'staff']},
#  {'id': 978,
#   'text': 'I wish they would change back to what it was before.',
#   'aspect': ['NULL']},
#  {'id': 979, 'text': 'The food now is inconsistent.', 'aspect': ['food']},
#  {'id': 980,
#   'text': "This is the kind of place you'd like to take all your friends to and still keep a secret.",
#   'aspect': ['place']},
#  {'id': 981,
#   'text': 'The setting is casual and romantic.',
#   'aspect': ['setting']},
#  {'id': 982, 'text': 'Prices are very good.', 'aspect': ['NULL']},
#  {'id': 983, 'text': 'The food is excellent! ', 'aspect': ['food']},
#  {'id': 984,
#   'text': "if you're daring, try the balsamic vinegar over icecream, it's wonderful!",
#   'aspect': ['balsamic vinegar over icecream']},
#  {'id': 985,
#   'text': 'Do not get the Go Go Hamburgers, no matter what the reviews say.',
#   'aspect': ['Go Go Hamburgers']},
#  {'id': 986,
#   'text': 'They were such a rip-off ($8.95 for four small meat patties in steamed buns) and not worth trying.',
#   'aspect': ['NULL']},
#  {'id': 987,
#   'text': 'The rest of the dim sum, though pricey by Chinatown standards, is worth it.',
#   'aspect': ['dim sum']},
#  {'id': 988,
#   'text': 'Steamed fresh so brought hot hot hot to your table.',
#   'aspect': ['NULL']},
#  {'id': 989,
#   'text': "The wait here is long for dim sum, but if you don't like sharing tables or if the typical raucous dim sum atmosphere is not your gig, this is a sleek (for Chinatown) alternative.",
#   'aspect': ['wait', 'atmosphere', 'NULL']},
#  {'id': 990,
#   'text': 'A few tips: skip the turnip cake, roast pork buns and egg custards.',
#   'aspect': ['turnip cake', 'roast pork buns', 'egg custards']},
#  {'id': 991,
#   'text': 'These are overpriced and you can get better just around the corner:',
#   'aspect': ['NULL']},
#  {'id': 992,
#   'text': '(1) turnip cakes at the little kiosk on east side of Mott St. just south of bayard',
#   'aspect': []},
#  {'id': 993,
#   'text': '(2) egg custards and pork buns at either bakery on west side of Mott street just south of Canal.',
#   'aspect': []},
#  {'id': 994,
#   'text': 'After passing by this restaurant for sometime I finally decided to go in and have dinner.',
#   'aspect': []},
#  {'id': 995, 'text': 'I was pleasantly suprised.', 'aspect': ['NULL']},
#  {'id': 996, 'text': 'The food was exceptional.', 'aspect': ['food']},
#  {'id': 997,
#   'text': 'The menu consisted of standard brassiere food, better then places like Balthazar etc.',
#   'aspect': []},
#  {'id': 998,
#   'text': 'I choose to go with one of the special, the braised lamb shank in red wine, which was excellent.',
#   'aspect': ['braised lamb shank in red wine']},
#  {'id': 999,
#   'text': 'The service was friendly and the atmosphere was casual.',
#   'aspect': ['service', 'atmosphere']},
#  {'id': 1000,
#   'text': 'The restaurant is a bit noisy but that is something that can be overlooked once you sit down and enjoy a great meal',
#   'aspect': ['meal', 'restaurant']},
#  ...]

# %%
def sen_process(kata):
    kata = re.sub('([.,!?()])', r' \1 ', kata) # match the punctuation characters and surround them by spaces,
    kata = re.sub('\s{2,}', ' ', kata)         # collapse multiple spaces to one space
    kata = re.sub(r'[^\w\s]', '', kata)
    words = kata.lower().split()
    return words

# %%
# tagging using POS tagging

# def post_tag(review):
#     tagged_review=[]
#     for each_review in tqdm(review):
#         review=nltk.word_tokeniza(each_review)
#         tagged_review.append(nltk.post_tag(review))
#     return tagged_review

# def posttagTest(review):
#     for word in review:
#         review=nltk.word_tokeniza(review)
#         tagged_reviews=nltk.post_tag(review)
#     return tagged_reviews

# %%
def IOB_tag(s, aspects):
    tags = ['O'] * len(s)
    for aspect in aspects:
        pre_index = 0
        for word in s: 
            if word in aspect: # 'good' in 'a good place'
                cur_index = s.index(word) 
                if cur_index - pre_index == 1: # inside an aspect term
                    tags[cur_index] = 'I'
                else:                       # beginning of an aspect term
                    tags[cur_index] = 'B'
                pre_index = cur_index 
    return tags

# %%
def opinion_rule(kata_postag):
    results_tree=[]
    grammar="NP: {<DT|PP|CD|RB>?<JJ|JJR|JJS>*<NN|NNS|PRpP|NNP}"
    cp=nltk.RegexpParser(grammar)
    for tag in kata_postag:
        results_tree.append(cp.parse(tag))
    return results_tree

# %%
def dict2df(kata):
    data = pd.DataFrame()
    for s in kata:
        sentence = {}
        sentence['Sentence #'] = s['id']
        sentence['Word'] = sen_process(s['text'])  # split text to words
        s_length = len(sentence['Word']) # the length of sentence, used to generate tag
        if len(s['aspect'])==0 or s['aspect'][0] == 'NULL': # tagging: if no aspect term
            sentence['Tag'] = ['O'] * s_length
        else:                                               # IOB format tag if aspect exist
            aspect_terms = [x.lower() for x in s['aspect']]  
            sentence['Tag'] = IOB_tag(sentence['Word'], aspect_terms)

        # convert each setence to dataframe 
        sentence_df = pd.DataFrame.from_dict(sentence)
        data = data.append(sentence_df, ignore_index=True)
    
    return data

# %%
data=dict2df(kata)
data
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5808\1493702247.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(sentence_df, ignore_index=True)
#        Sentence #      Word Tag
# 0               1   judging   O
# 1               1      from   O
# 2               1  previous   O
# 3               1     posts   O
# 4               1      this   O
# ...           ...       ...  ..
# 25031        2000   someone   O
# 25032        2000     would   O
# 25033        2000   retrain   O
# 25034        2000       the   O
# 25035        2000     staff   B
#
# [25036 rows x 3 columns]

# %%
datatag=data.groupby('Tag').count()
datatag
# Out:
#      Sentence #   Word
# Tag
# B          1727   1727
# I          1135   1135
# O         22174  22174

# %%
datatag['Word']
# Out:
# Tag
# B     1727
# I     1135
# O    22174
# Name: Word, dtype: int64

# %%
datauji=Path.cwd().parent.joinpath(r'C:\Users\USER\Documents\DataScience\Skripsiiuu\ATE-XGBoost\Dataset\test.xml')

extract=None
with datauji.open(encoding="utf-8")as f:
    extract=BeautifulSoup(f.read().strip(),"lxml-xml")
if extract is None:
    raise Exception("Data XML not found")
sentence_nodes=extract.find_all("sentence")


katauji = soup2dict(sentence_nodes)
katauji

ujidata=dict2df(katauji)
ujidata
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5808\1493702247.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(sentence_df, ignore_index=True)
#       Sentence #    Word Tag
# 0              1     yum   O
# 1              2  serves   O
# 2              2  really   O
# 3              2    good   O
# 4              2   sushi   B
# ...          ...     ...  ..
# 8538         676     the   O
# 8539         676    view   B
# 8540         676     was   O
# 8541         676    good   O
# 8542         676     too   O
#
# [8543 rows x 3 columns]

# %%
def read_data(file_path):
    # 1 raw data to soup
    soup = None
    with file_path.open(encoding="utf-8") as f:
        soup = BeautifulSoup(f.read().strip(), "lxml-xml")
    if soup is None:
        raise Exception("Can't read xml file")
    sentence_nodes = soup.find_all("sentence")

    # 2  convert soup object to a list of dictionaries
    sentences = soup2dict(sentence_nodes)

    # 3 list to dataframe
    data = dict2df(sentences)
    
    return data

# %%
#saving to csv file
data.to_csv("Dataset/Train_Restaurant.csv")

# %%
#saving test data to csv file too
ujidata.to_csv("Dataset/Test_Restaurant.csv")

# %%
#Using XGBoost
